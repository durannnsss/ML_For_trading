# %% [markdown]
# # Notebook Instructions
#
# 1. If you are new to Jupyter notebooks, please go through this introductory manual <a href='https://quantra.quantinsti.com/quantra-notebook' target="_blank">here</a>.
# 1. Any changes made in this notebook would be lost after you close the browser window. **You can download the notebook to save your work on your PC.**
# 1. Before running this notebook on your local PC:<br>
# i.  You need to set up a Python environment and the relevant packages on your local PC. To do so, go through the section on "**Run Codes Locally on Your Machine**" in the course.<br>
# ii. You need to **download the zip file available in the last unit** of this course. The zip file contains the data files and/or python modules that might be required to run this notebook.

# %% [markdown]
# # Backtesting the ML Model To Predict Strategy
#
# In the previous notebook, we predicted the strategy labels using the LSTM model. In this notebook, we will backtest the labels predicted by the model designed in the previous notebook and check the results.
#
# The notebook is structured as follows:
# 1. [Import the Data](#import)
# 2. [Strategy Parameters](#parameters)
# 3. [Entry Condition](#entry)
# 4. [Exit Condition](#exit)
# 5. [Backtesting](#backtesting)
#
# ## Import Libraries

# %%
# For data manipulation
import numpy as np
import pandas as pd

# Datetime manipulation
from datetime import timedelta

# For plotting
import matplotlib.pyplot as plt

# To suppress warnings
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id='import'></a>
# ## Import the Data
#
# Import the following files
# 1. `spx_eom_expiry_options_2010_2022.bz2` as `options_data`
# 2. `underlying_data_model_mlo.csv` as `underlying_data`
# 3. `predicted_labels_lstm_mlo.csv` as `pred_labels`
# 4. `strategies_combinations_mlo.csv` as `strategies`
#
# These files are available in the zip file of the unit 'Python Codes and Data' in the 'Course Summary' section.

# %%
# Import options chain data and set the index
options_data = pd.read_pickle(
    "../data_modules/spx_eom_expiry_options_2010_2022.bz2")
options_data.columns = options_data.columns.str.replace(
    "[", "").str.replace("]", "").str.strip()
options_data.index = pd.to_datetime(options_data.index)
options_data['date'] = options_data.index

# Import the predicted labels of test data
pred_labels = pd.read_csv(
    '../data_modules/predicted_labels_lstm_mlo.csv', index_col=0)['0'].values

# Import the underlying data with option chain data and target variable
underlying_data = pd.read_csv(
    '../data_modules/underlying_data_model_mlo.csv', index_col='quote_date')

# Backtesting on test data
test_size = 484
underlying_asset_data = underlying_data[-test_size:]
underlying_asset_data = underlying_asset_data.dropna()

# Create a column 'pred_strategy' with predicted labels
underlying_asset_data.loc[:, 'pred_strategy'] = pred_labels
underlying_asset_data.index = pd.to_datetime(underlying_asset_data.index)
underlying_asset_data['index'] = underlying_asset_data.index
underlying_asset_data.pred_strategy = underlying_asset_data.pred_strategy

# Import the list of strategies
strategies = pd.read_csv(
    '../data_modules/strategies_combinations_mlo.csv', index_col='Unnamed: 0')

# %% [markdown]
# <a id='parameters'></a>
# ## Strategy Parameters
#
# We will set the stop-loss and take-profit percentage to 40% and 40% of the net entry premium respectively. You can try changing this to see how it affects the backtest results. However, if the SL is kept too low, then it might get hit too frequently. On the other hand, if we keep it too high, then it might not hit at all.
#
# The `days_to_exit_after_entry` is set to 3 since we want to hold positions only for a maximum of 3 trading days.

# %%
config = {

    'stop_loss_percentage': 40,
    'take_profit_percentage': 40,
    'days_to_exit_after_entry': 3
}

# %% [markdown]
# <a id='entry'></a>
# ## Entry Condition
#
# We will enter the trade as per the strategy labels predicted by the model which were stored in the `pred_strategy` column of `underlying_asset_data`. Let's create a column `signal` in `underlying_asset_data` to store the signal as 1 when a strategy is predicted by the model.

# %%
# Creating signal column for each strategy predicted by the model
for strategy_ in underlying_asset_data.pred_strategy.unique():
    underlying_asset_data[strategy_+'_signal'] = [1 if k ==
                                                  strategy_ else 0 for k in underlying_asset_data.pred_strategy]

# %% [markdown]
# <a id='exit'></a>
# ## Exit Condition
#
# The trade will be exited if one of the following conditions is met.
# 1. When current profit is greater than take profit
# 2. When current loss is greater than stop loss
# 3. The trade is held for `days_to_exit_after_entry`
# 4. If the signal is 0

# %% [markdown]
# <a id='backtesting'></a>
# ## Backtesting and Performance Analysis
#
# We will loop over each of the dates in the data for each strategy in the list of predicted strategies, set up the strategy when entry conditions are met, exit when exit conditions are met, and update the trade in `round_trips_details`. `mark_to_market` dataframe contains the premiums of the strategy on each date between the entry date and exit date.
#
# We will backtest the strategies using the following steps:
#
# **Step-1**: Create dataframes `round_trips_details`, `trades` and `mark_to_market` for storing round trips, trades and mtm.
#
# **Step-2**: Define a function `add_to_mtm` which stores daily mark_to_market values for the strategy. It takes the existing `mark_to_market` dataframe, `option_strategy` and `trading_date` as inputs.
#
# **Step-3**: Define a function `get_premium` to get the premium for the multiple positions as per strategy. It takes `options_strategy` and `options_data` as inputs.
#
# **Step-4**: Define a function `strategy_generator` to set up the strategies. It takes `options_data`, `strategies` and  `underlying_asset_data`.
#
# **Step-5**: Initialise `current_position`, `trade_num`, which is the number of trades, `cum_pnl` to 0 and set the `entry_flag` to `False`.
#
# **Step-6**: We also set the `start_date` for backtesting.

# %%
# Create dataframes for round trips, storing trades, and mtm
round_trips_details = pd.DataFrame()
trades = pd.DataFrame()
mark_to_market = pd.DataFrame()

# Function for calculating mtm
def add_to_mtm(mark_to_market, option_strategy, trading_date):
    option_strategy['Date'] = trading_date
    mark_to_market = pd.concat([mark_to_market, option_strategy])
    return mark_to_market

# Function for fetching premium
def get_premium(options_strategy, options_data):

    strike = options_strategy['Strike Price']
    option_type = options_strategy['Option Type']
    if option_type == 'call':
        return options_data[options_data['STRIKE'] == strike].C_LAST
    if option_type == 'put':
        return options_data[options_data['STRIKE'] == strike].P_LAST
    if option_type == 'stock':
        return options_data[options_data['STRIKE'] == strike].UNDERLYING_LAST
    return 0

# Function to create strategy
def strategy_generator(options_data_, strategies, underlying_asset_data):
    strategies = strategies.reset_index().drop(['index'], axis=1)
    for str_ in range(0, len(strategies)):

        n_pos = len([x for x in strategies.loc[str_].values[:3] if x != 0])
        strategy = pd.DataFrame(
            columns=['Option Type', 'Strike Price', 'position', 'premium'])
        atm_strike_price = underlying_asset_data.loc[options_data_.index[0]
                                                     ].atm_strike_price
        for leg in range(0, n_pos):
            contract = strategies.loc[str_][:3][strategies.loc[str_]
                                                [:3] != 0].index[leg]
            position = strategies.loc[str_][:3][strategies.loc[str_]
                                                [:3] != 0][leg]
            strategy.loc[leg] = [contract, atm_strike_price, position, np.nan]
            strategy['premium'] = strategy.apply(
                lambda r: get_premium(r, options_data_), axis=1)
        return strategy


# Initialise current position, the number of trades and cumulative pnl to 0
current_position = 0
trade_num = 0
cum_pnl = 0

# Set exit flag to False
exit_flag = False

# Creating dataframe backtest_data for further calculations
backtest_data = underlying_asset_data
backtest_data.index = backtest_data['index']
backtest_data = backtest_data.drop(['index'], axis=1)

# Set a start date for backtesting
start_date = backtest_data.index[0]

# %% [markdown]
# Perform the following steps iteratively for the dates in the backtest period for every strategy in the predicted labels.
#
# **Step-7**: For a given date, if there is no open position and entry conditions are met, we will set up the strategy.
#
# **Step-8**: For a given date, if there is an open position, we exit the trade if stop-loss/take-profit gets hit or if the trade was held for more than `days_to_exit_after_entry` and update round trips.
#
# **Step-9**: Finally, we calculate the pnl for the trade and also the cumulative pnl.

# %%
# Function to create strategy
def strategy_generator(options_data_, strategies, underlying_asset_data):
    strategies = strategies.reset_index().drop(['index'], axis=1)
    for str_ in range(0, len(strategies)):

        n_pos = len([x for x in strategies.loc[str_].values[:3] if x != 0])
        strategy = pd.DataFrame(
            columns=['Option Type', 'Strike Price', 'position', 'premium'])
        atm_strike_price = underlying_asset_data.loc[options_data_.index[0]
                                                     ].atm_strike_price
        for leg in range(0, n_pos):
            contract = strategies.loc[str_][:3][strategies.loc[str_]
                                                [:3] != 0].index[leg]
            position = strategies.loc[str_][:3][strategies.loc[str_]
                                                [:3] != 0][leg]
            strategy.loc[leg] = [contract, atm_strike_price, position, np.nan]
            strategy['premium'] = strategy.apply(
                lambda r: get_premium(r, options_data_), axis=1)
        return strategy

# %%
for strategy_name in backtest_data.pred_strategy.unique():
    current_position = 0
    print('*********', strategy_name)
    backtest_data['signal'] = backtest_data[strategy_name+'_signal']

    for i in backtest_data.loc[start_date:].index:

        if (current_position == 0) & (backtest_data.loc[i, 'signal'] != 0):

            # Step-5: Set up strategy
            try:
                options_data_daily = options_data.loc[i]
            except:
                continue

            # If signal is 1 we will set up the strategy
            if backtest_data.loc[i, 'signal'] == 1:
                strategy_cal = strategy_generator(
                    options_data_daily, strategies[strategies.strategy == strategy_name], backtest_data)
            else:
                continue

            # Populate the trades dataframe
            trades = strategy_cal.copy()
            trades['entry_date'] = i
            trades.rename(columns={'premium': 'entry_price'}, inplace=True)

            # Calculate net premium
            net_premium = round(
                (strategy_cal.position * strategy_cal.premium).sum(), 1)

            # Compute SL and TP for the trade
            premium_sign = np.sign(net_premium)
            sl = net_premium * \
                (1 - config['stop_loss_percentage']*premium_sign/100)
            tp = net_premium * \
                (1 + config['take_profit_percentage']*premium_sign/100)

            # Update current position
            current_position = backtest_data.loc[i, 'signal']
            last_trade_date = i

            # Update mark_to_market dataframe
            mark_to_market = add_to_mtm(mark_to_market, strategy_cal, i)

            # Increase number of trades by 1
            trade_num += 1
            print("-"*30)

            # Print trade details
            print(
                f"Trade No: {trade_num} | Entry | Date: {i} | Premium: {net_premium*-1} | Position: {current_position}")

        # Step-7 :
        elif current_position != 0:

            # Update net premium
            try:
                options_data_daily = options_data.loc[i]
                strategy_cal['premium'] = strategy_cal.apply(
                    lambda r: get_premium(r, options_data_daily), axis=1)
            except:
                continue
            net_premium = (strategy_cal.position * strategy_cal.premium).sum()

            # Update mark_to_market dataframe
            mark_to_market = add_to_mtm(mark_to_market, strategy_cal, i)

            # Exit the trade if any of the exit condition is met
            if backtest_data.loc[i, 'signal'] != current_position:
                exit_type = 'Expiry or Signal Based'
                exit_flag = True

            elif net_premium < sl:
                exit_type = 'SL'
                exit_flag = True

            elif net_premium > tp:
                exit_type = 'TP'
                exit_flag = True

            elif (i-last_trade_date).days > config['days_to_exit_after_entry']:
                exit_type = 'days'
                exit_flag = True

            if exit_flag:

                # Check that the data is present for all strike prices on the exit date
                if strategy_cal.premium.isna().sum() > 0:
                    print(
                        f"Data missing for the required strike prices on {i}, Not adding to trade logs.")
                    current_position = 0
                    continue

                # Append the trades dataframe
                trades['exit_date'] = i
                trades['exit_type'] = exit_type
                trades['exit_price'] = strategy_cal.premium

                # Add the trade logs to round trip details
                round_trips_details = pd.concat([round_trips_details, trades])

                # Calculate net premium at exit
                net_premium = round(
                    (strategy_cal.position * strategy_cal.premium).sum(), 1)

                # Calculate net premium on entry
                entry_net_premium = (
                    trades.position * trades.entry_price).sum()

                # Step-8: Calculate pnl for the trade
                trade_pnl = round(net_premium - entry_net_premium, 1)

                # Calculate cumulative pnl
                cum_pnl += trade_pnl
                cum_pnl = round(cum_pnl, 1)

                # Print trade details
                print(
                    f"Trade No: {trade_num} | Exit Type: {exit_type} | Date: {i} | Premium: {net_premium} | PnL: {trade_pnl} | Cum PnL: {cum_pnl}")

                # Update current position to 0
                current_position = 0

                # Set exit flag to false
                exit_flag = False
# Out:
# ********* strategy_6
# ------------------------------
# Trade No: 1 | Entry | Date: 2020-10-08 00:00:00 | Premium: -3.6 | Position: 1
# Trade No: 1 | Exit Type: Expiry or Signal Based | Date: 2020-10-09 00:00:00 | Premium: -27.5 | PnL: -31.1 | Cum PnL: -31.1
# ------------------------------
# Trade No: 2 | Entry | Date: 2020-10-19 00:00:00 | Premium: -1.0 | Position: 1
# Trade No: 2 | Exit Type: Expiry or Signal Based | Date: 2020-10-20 00:00:00 | Premium: -18.8 | PnL: -19.8 | Cum PnL: -50.9
# ------------------------------
# Trade No: 3 | Entry | Date: 2020-12-28 00:00:00 | Premium: 1.2 | Position: 1
# Trade No: 3 | Exit Type: Expiry or Signal Based | Date: 2020-12-29 00:00:00 | Premium: 6.4 | PnL: 7.6 | Cum PnL: -43.3
# ------------------------------
# Trade No: 4 | Entry | Date: 2021-01-05 00:00:00 | Premium: 3.7 | Position: 1
# Trade No: 4 | Exit Type: Expiry or Signal Based | Date: 2021-01-06 00:00:00 | Premium: -43.5 | PnL: -39.8 | Cum PnL: -83.1
# ------------------------------
# Trade No: 5 | Entry | Date: 2021-01-08 00:00:00 | Premium: -1.8 | Position: 1
# Trade No: 5 | Exit Type: Expiry or Signal Based | Date: 2021-01-11 00:00:00 | Premium: 21.0 | PnL: 19.2 | Cum PnL: -63.9
# ------------------------------
# Trade No: 6 | Entry | Date: 2021-04-13 00:00:00 | Premium: 0.9 | Position: 1
# Trade No: 6 | Exit Type: Expiry or Signal Based | Date: 2021-04-14 00:00:00 | Premium: 17.2 | PnL: 18.1 | Cum PnL: -45.8
# ------------------------------
# Trade No: 7 | Entry | Date: 2021-05-20 00:00:00 | Premium: -2.5 | Position: 1
# Trade No: 7 | Exit Type: Expiry or Signal Based | Date: 2021-05-21 00:00:00 | Premium: 2.9 | PnL: 0.4 | Cum PnL: -45.4
# ------------------------------
# Trade No: 8 | Entry | Date: 2021-06-16 00:00:00 | Premium: 4.2 | Position: 1
# Trade No: 8 | Exit Type: Expiry or Signal Based | Date: 2021-06-17 00:00:00 | Premium: -5.4 | PnL: -1.2 | Cum PnL: -46.6
# ------------------------------
# Trade No: 9 | Entry | Date: 2021-08-24 00:00:00 | Premium: -0.8 | Position: 1
# Trade No: 9 | Exit Type: Expiry or Signal Based | Date: 2021-08-25 00:00:00 | Premium: -12.7 | PnL: -13.4 | Cum PnL: -60.0
# ------------------------------
# Trade No: 10 | Entry | Date: 2021-09-28 00:00:00 | Premium: -0.4 | Position: 1
# Trade No: 10 | Exit Type: Expiry or Signal Based | Date: 2021-09-29 00:00:00 | Premium: -1.6 | PnL: -2.0 | Cum PnL: -62.0
# ------------------------------
# Trade No: 11 | Entry | Date: 2021-11-02 00:00:00 | Premium: -10.0 | Position: 1
# Trade No: 11 | Exit Type: SL | Date: 2021-11-04 00:00:00 | Premium: -37.4 | PnL: -47.4 | Cum PnL: -109.4
# ------------------------------
# Trade No: 12 | Entry | Date: 2021-11-08 00:00:00 | Premium: -1.9 | Position: 1
# Trade No: 12 | Exit Type: TP | Date: 2021-11-09 00:00:00 | Premium: 21.8 | PnL: 19.9 | Cum PnL: -89.5
# ------------------------------
# Trade No: 13 | Entry | Date: 2021-12-13 00:00:00 | Premium: 3.9 | Position: 1
# Trade No: 13 | Exit Type: Expiry or Signal Based | Date: 2021-12-14 00:00:00 | Premium: 53.0 | PnL: 56.9 | Cum PnL: -32.6
# ------------------------------
# Trade No: 14 | Entry | Date: 2022-01-03 00:00:00 | Premium: -13.6 | Position: 1
# Trade No: 14 | Exit Type: Expiry or Signal Based | Date: 2022-01-04 00:00:00 | Premium: 2.2 | PnL: -11.4 | Cum PnL: -44.0
# ------------------------------
# Trade No: 15 | Entry | Date: 2022-01-05 00:00:00 | Premium: 14.5 | Position: 1
# Trade No: 15 | Exit Type: TP | Date: 2022-01-06 00:00:00 | Premium: -0.3 | PnL: 14.2 | Cum PnL: -29.8
# ------------------------------
# Trade No: 16 | Entry | Date: 2022-01-13 00:00:00 | Premium: 15.1 | Position: 1
# Trade No: 16 | Exit Type: Expiry or Signal Based | Date: 2022-01-14 00:00:00 | Premium: 0.3 | PnL: 15.4 | Cum PnL: -14.4
# ------------------------------
# Trade No: 17 | Entry | Date: 2022-01-21 00:00:00 | Premium: 2.5 | Position: 1
# Trade No: 17 | Exit Type: Expiry or Signal Based | Date: 2022-01-24 00:00:00 | Premium: -11.3 | PnL: -8.8 | Cum PnL: -23.2
# ------------------------------
# Trade No: 18 | Entry | Date: 2022-02-08 00:00:00 | Premium: -7.5 | Position: 1
# Trade No: 18 | Exit Type: Expiry or Signal Based | Date: 2022-02-09 00:00:00 | Premium: -57.1 | PnL: -64.6 | Cum PnL: -87.8
# ------------------------------
# Trade No: 19 | Entry | Date: 2022-02-14 00:00:00 | Premium: -6.4 | Position: 1
# Trade No: 19 | Exit Type: SL | Date: 2022-02-15 00:00:00 | Premium: -59.1 | PnL: -65.5 | Cum PnL: -153.3
# ------------------------------
# Trade No: 20 | Entry | Date: 2022-02-17 00:00:00 | Premium: 16.9 | Position: 1
# Trade No: 20 | Exit Type: TP | Date: 2022-02-18 00:00:00 | Premium: 30.2 | PnL: 47.1 | Cum PnL: -106.2
# ------------------------------
# Trade No: 21 | Entry | Date: 2022-02-22 00:00:00 | Premium: -5.9 | Position: 1
# Trade No: 21 | Exit Type: Expiry or Signal Based | Date: 2022-02-23 00:00:00 | Premium: 78.6 | PnL: 72.7 | Cum PnL: -33.5
# ------------------------------
# Trade No: 22 | Entry | Date: 2022-03-03 00:00:00 | Premium: 11.1 | Position: 1
# Trade No: 22 | Exit Type: Expiry or Signal Based | Date: 2022-03-04 00:00:00 | Premium: -11.1 | PnL: 0.0 | Cum PnL: -33.5
# ------------------------------
# Trade No: 23 | Entry | Date: 2022-03-08 00:00:00 | Premium: 43.6 | Position: 1
# Trade No: 23 | Exit Type: TP | Date: 2022-03-09 00:00:00 | Premium: -3.9 | PnL: 39.7 | Cum PnL: 6.2
# ------------------------------
# Trade No: 24 | Entry | Date: 2022-03-15 00:00:00 | Premium: -30.6 | Position: 1
# Trade No: 24 | Exit Type: SL | Date: 2022-03-16 00:00:00 | Premium: -21.8 | PnL: -52.4 | Cum PnL: -46.2
# ------------------------------
# Trade No: 25 | Entry | Date: 2022-03-21 00:00:00 | Premium: -0.8 | Position: 1
# Trade No: 25 | Exit Type: Expiry or Signal Based | Date: 2022-03-22 00:00:00 | Premium: -47.4 | PnL: -48.2 | Cum PnL: -94.4
# ------------------------------
# Trade No: 26 | Entry | Date: 2022-03-30 00:00:00 | Premium: 0.2 | Position: 1
# Trade No: 26 | Exit Type: TP | Date: 2022-03-31 00:00:00 | Premium: 59.9 | PnL: 60.1 | Cum PnL: -34.3
# ------------------------------
# Trade No: 27 | Entry | Date: 2022-04-01 00:00:00 | Premium: -18.5 | Position: 1
# Trade No: 27 | Exit Type: SL | Date: 2022-04-04 00:00:00 | Premium: -21.3 | PnL: -39.8 | Cum PnL: -74.1
# ------------------------------
# Trade No: 28 | Entry | Date: 2022-04-05 00:00:00 | Premium: -5.8 | Position: 1
# Trade No: 28 | Exit Type: TP | Date: 2022-04-06 00:00:00 | Premium: 58.6 | PnL: 52.8 | Cum PnL: -21.3
# ------------------------------
# Trade No: 29 | Entry | Date: 2022-04-07 00:00:00 | Premium: 11.5 | Position: 1
# Trade No: 29 | Exit Type: TP | Date: 2022-04-08 00:00:00 | Premium: 9.2 | PnL: 20.7 | Cum PnL: -0.6
# ------------------------------
# Trade No: 30 | Entry | Date: 2022-04-11 00:00:00 | Premium: 17.0 | Position: 1
# Trade No: 30 | Exit Type: TP | Date: 2022-04-12 00:00:00 | Premium: 0.2 | PnL: 17.2 | Cum PnL: 16.6
# ------------------------------
# Trade No: 31 | Entry | Date: 2022-04-13 00:00:00 | Premium: 0.3 | Position: 1
# Trade No: 31 | Exit Type: Expiry or Signal Based | Date: 2022-04-14 00:00:00 | Premium: 47.3 | PnL: 47.6 | Cum PnL: 64.2
# ------------------------------
# Trade No: 32 | Entry | Date: 2022-04-28 00:00:00 | Premium: -5.0 | Position: 1
# Trade No: 32 | Exit Type: Expiry or Signal Based | Date: 2022-04-29 00:00:00 | Premium: 138.0 | PnL: 133.0 | Cum PnL: 197.2
# ------------------------------
# Trade No: 33 | Entry | Date: 2022-05-09 00:00:00 | Premium: 37.8 | Position: 1
# Trade No: 33 | Exit Type: TP | Date: 2022-05-10 00:00:00 | Premium: -2.6 | PnL: 35.2 | Cum PnL: 232.4
# ------------------------------
# Trade No: 34 | Entry | Date: 2022-05-12 00:00:00 | Premium: -15.5 | Position: 1
# Trade No: 34 | Exit Type: Expiry or Signal Based | Date: 2022-05-13 00:00:00 | Premium: 15.5 | PnL: 0.0 | Cum PnL: 232.4
# ------------------------------
# Trade No: 35 | Entry | Date: 2022-05-17 00:00:00 | Premium: -41.1 | Position: 1
# Trade No: 35 | Exit Type: Expiry or Signal Based | Date: 2022-05-18 00:00:00 | Premium: 152.9 | PnL: 111.8 | Cum PnL: 344.2
# ------------------------------
# Trade No: 36 | Entry | Date: 2022-06-01 00:00:00 | Premium: 7.9 | Position: 1
# Trade No: 36 | Exit Type: SL | Date: 2022-06-02 00:00:00 | Premium: -20.1 | PnL: -12.2 | Cum PnL: 332.0
# ------------------------------
# Trade No: 37 | Entry | Date: 2022-06-06 00:00:00 | Premium: 2.3 | Position: 1
# Trade No: 37 | Exit Type: SL | Date: 2022-06-07 00:00:00 | Premium: -9.8 | PnL: -7.5 | Cum PnL: 324.5
# ------------------------------
# Trade No: 38 | Entry | Date: 2022-06-08 00:00:00 | Premium: 2.1 | Position: 1
# Trade No: 38 | Exit Type: TP | Date: 2022-06-09 00:00:00 | Premium: 16.2 | PnL: 18.3 | Cum PnL: 342.8
# ------------------------------
# Trade No: 39 | Entry | Date: 2022-06-10 00:00:00 | Premium: 10.2 | Position: 1
# Trade No: 39 | Exit Type: TP | Date: 2022-06-13 00:00:00 | Premium: 137.5 | PnL: 147.7 | Cum PnL: 490.5
# ------------------------------
# Trade No: 40 | Entry | Date: 2022-06-14 00:00:00 | Premium: -7.8 | Position: 1
# Trade No: 40 | Exit Type: Expiry or Signal Based | Date: 2022-06-15 00:00:00 | Premium: 7.8 | PnL: 0.0 | Cum PnL: 490.5
# ------------------------------
# Trade No: 41 | Entry | Date: 2022-06-27 00:00:00 | Premium: -6.5 | Position: 1
# Trade No: 41 | Exit Type: Expiry or Signal Based | Date: 2022-06-28 00:00:00 | Premium: 73.1 | PnL: 66.6 | Cum PnL: 557.1
# ------------------------------
# Trade No: 42 | Entry | Date: 2022-07-01 00:00:00 | Premium: 1.2 | Position: 1
# Trade No: 42 | Exit Type: days | Date: 2022-07-05 00:00:00 | Premium: -1.2 | PnL: 0.1 | Cum PnL: 557.2
# ------------------------------
# Trade No: 43 | Entry | Date: 2022-07-06 00:00:00 | Premium: -17.1 | Position: 1
# Trade No: 43 | Exit Type: Expiry or Signal Based | Date: 2022-07-07 00:00:00 | Premium: -18.8 | PnL: -35.9 | Cum PnL: 521.3
# ------------------------------
# Trade No: 44 | Entry | Date: 2022-07-08 00:00:00 | Premium: 3.3 | Position: 1
# Trade No: 44 | Exit Type: TP | Date: 2022-07-11 00:00:00 | Premium: 45.7 | PnL: 49.0 | Cum PnL: 570.3
# ------------------------------
# Trade No: 45 | Entry | Date: 2022-07-13 00:00:00 | Premium: 14.6 | Position: 1
# Trade No: 45 | Exit Type: TP | Date: 2022-07-14 00:00:00 | Premium: 10.0 | PnL: 24.6 | Cum PnL: 594.9
# ------------------------------
# Trade No: 46 | Entry | Date: 2022-07-19 00:00:00 | Premium: 0.5 | Position: 1
# Trade No: 46 | Exit Type: Expiry or Signal Based | Date: 2022-07-20 00:00:00 | Premium: -32.5 | PnL: -32.0 | Cum PnL: 562.9
# ------------------------------
# Trade No: 47 | Entry | Date: 2022-08-01 00:00:00 | Premium: 2.2 | Position: 1
# Trade No: 47 | Exit Type: TP | Date: 2022-08-02 00:00:00 | Premium: 1.0 | PnL: 3.2 | Cum PnL: 566.1
# ------------------------------
# Trade No: 48 | Entry | Date: 2022-08-03 00:00:00 | Premium: -23.1 | Position: 1
# Trade No: 48 | Exit Type: days | Date: 2022-08-08 00:00:00 | Premium: 21.2 | PnL: -1.9 | Cum PnL: 564.2
# ------------------------------
# Trade No: 49 | Entry | Date: 2022-08-10 00:00:00 | Premium: -0.6 | Position: 1
# Trade No: 49 | Exit Type: TP | Date: 2022-08-11 00:00:00 | Premium: 1.8 | PnL: 1.2 | Cum PnL: 565.4
# ------------------------------
# Trade No: 50 | Entry | Date: 2022-08-12 00:00:00 | Premium: -5.8 | Position: 1
# Trade No: 50 | Exit Type: Expiry or Signal Based | Date: 2022-08-15 00:00:00 | Premium: -16.0 | PnL: -21.8 | Cum PnL: 543.6
# ********* strategy_3
# ------------------------------
# Trade No: 51 | Entry | Date: 2020-10-09 00:00:00 | Premium: 57.5 | Position: 1
# Trade No: 51 | Exit Type: SL | Date: 2020-10-12 00:00:00 | Premium: -103.3 | PnL: -45.8 | Cum PnL: 497.8
# ------------------------------
# Trade No: 52 | Entry | Date: 2020-10-21 00:00:00 | Premium: 60.6 | Position: 1
# Trade No: 52 | Exit Type: TP | Date: 2020-10-26 00:00:00 | Premium: -20.2 | PnL: 40.4 | Cum PnL: 538.2
# ------------------------------
# Trade No: 53 | Entry | Date: 2020-10-27 00:00:00 | Premium: 31.7 | Position: 1
# Trade No: 53 | Exit Type: TP | Date: 2020-10-28 00:00:00 | Premium: -2.8 | PnL: 28.9 | Cum PnL: 567.1
# ------------------------------
# Trade No: 54 | Entry | Date: 2020-10-29 00:00:00 | Premium: 28.8 | Position: 1
# Trade No: 54 | Exit Type: TP | Date: 2020-10-30 00:00:00 | Premium: -0.0 | PnL: 28.8 | Cum PnL: 595.9
# ------------------------------
# Trade No: 55 | Entry | Date: 2020-11-02 00:00:00 | Premium: 110.4 | Position: 1
# Trade No: 55 | Exit Type: Expiry or Signal Based | Date: 2020-11-03 00:00:00 | Premium: -110.4 | PnL: 0.0 | Cum PnL: 595.9
# ------------------------------
# Trade No: 56 | Entry | Date: 2020-11-13 00:00:00 | Premium: 43.6 | Position: 1
# Trade No: 56 | Exit Type: SL | Date: 2020-11-16 00:00:00 | Premium: -66.7 | PnL: -23.1 | Cum PnL: 572.8
# ------------------------------
# Trade No: 57 | Entry | Date: 2020-11-17 00:00:00 | Premium: 41.2 | Position: 1
# Trade No: 57 | Exit Type: Expiry or Signal Based | Date: 2020-11-19 00:00:00 | Premium: -24.6 | PnL: 16.6 | Cum PnL: 589.4
# ------------------------------
# Trade No: 58 | Entry | Date: 2020-11-24 00:00:00 | Premium: 24.1 | Position: 1
# Trade No: 58 | Exit Type: TP | Date: 2020-11-25 00:00:00 | Premium: -13.9 | PnL: 10.2 | Cum PnL: 599.6
# ------------------------------
# Trade No: 59 | Entry | Date: 2020-11-30 00:00:00 | Premium: 0.1 | Position: 1
# Trade No: 59 | Exit Type: SL | Date: 2020-12-01 00:00:00 | Premium: -103.3 | PnL: -103.2 | Cum PnL: 496.4
# ------------------------------
# Trade No: 60 | Entry | Date: 2020-12-02 00:00:00 | Premium: 67.7 | Position: 1
# Trade No: 60 | Exit Type: Expiry or Signal Based | Date: 2020-12-07 00:00:00 | Premium: -69.8 | PnL: -2.1 | Cum PnL: 494.3
# ------------------------------
# Trade No: 61 | Entry | Date: 2020-12-21 00:00:00 | Premium: 42.6 | Position: 1
# Trade No: 61 | Exit Type: Expiry or Signal Based | Date: 2020-12-22 00:00:00 | Premium: -35.1 | PnL: 7.5 | Cum PnL: 501.8
# ------------------------------
# Trade No: 62 | Entry | Date: 2020-12-23 00:00:00 | Premium: 37.3 | Position: 1
# Trade No: 62 | Exit Type: Expiry or Signal Based | Date: 2020-12-28 00:00:00 | Premium: -55.6 | PnL: -18.3 | Cum PnL: 483.5
# ------------------------------
# Trade No: 63 | Entry | Date: 2020-12-31 00:00:00 | Premium: 2.6 | Position: 1
# Trade No: 63 | Exit Type: SL | Date: 2021-01-04 00:00:00 | Premium: -45.3 | PnL: -42.7 | Cum PnL: 440.8
# ------------------------------
# Trade No: 64 | Entry | Date: 2021-01-11 00:00:00 | Premium: 63.0 | Position: 1
# Trade No: 64 | Exit Type: TP | Date: 2021-01-15 00:00:00 | Premium: -35.9 | PnL: 27.1 | Cum PnL: 467.9
# ------------------------------
# Trade No: 65 | Entry | Date: 2021-01-19 00:00:00 | Premium: 43.5 | Position: 1
# Trade No: 65 | Exit Type: Expiry or Signal Based | Date: 2021-01-20 00:00:00 | Premium: -76.5 | PnL: -33.0 | Cum PnL: 434.9
# ------------------------------
# Trade No: 66 | Entry | Date: 2021-01-26 00:00:00 | Premium: 23.1 | Position: 1
# Trade No: 66 | Exit Type: Expiry or Signal Based | Date: 2021-01-27 00:00:00 | Premium: -5.0 | PnL: 18.1 | Cum PnL: 453.0
# ------------------------------
# Trade No: 67 | Entry | Date: 2021-01-28 00:00:00 | Premium: 25.7 | Position: 1
# Trade No: 67 | Exit Type: Expiry or Signal Based | Date: 2021-01-29 00:00:00 | Premium: -0.0 | PnL: 25.7 | Cum PnL: 478.7
# ------------------------------
# Trade No: 68 | Entry | Date: 2021-02-01 00:00:00 | Premium: 88.6 | Position: 1
# Trade No: 68 | Exit Type: Expiry or Signal Based | Date: 2021-02-03 00:00:00 | Premium: -110.2 | PnL: -21.6 | Cum PnL: 457.1
# ------------------------------
# Trade No: 69 | Entry | Date: 2021-02-18 00:00:00 | Premium: 37.1 | Position: 1
# Trade No: 69 | Exit Type: TP | Date: 2021-02-22 00:00:00 | Premium: -11.8 | PnL: 25.3 | Cum PnL: 482.4
# ------------------------------
# Trade No: 70 | Entry | Date: 2021-02-25 00:00:00 | Premium: 27.8 | Position: 1
# Trade No: 70 | Exit Type: SL | Date: 2021-03-01 00:00:00 | Premium: -128.4 | PnL: -100.6 | Cum PnL: 381.8
# ------------------------------
# Trade No: 71 | Entry | Date: 2021-03-11 00:00:00 | Premium: 67.5 | Position: 1
# Trade No: 71 | Exit Type: Expiry or Signal Based | Date: 2021-03-12 00:00:00 | Premium: -56.3 | PnL: 11.2 | Cum PnL: 393.0
# ------------------------------
# Trade No: 72 | Entry | Date: 2021-03-15 00:00:00 | Premium: 37.3 | Position: 1
# Trade No: 72 | Exit Type: Expiry or Signal Based | Date: 2021-03-18 00:00:00 | Premium: -23.1 | PnL: 14.2 | Cum PnL: 407.2
# ------------------------------
# Trade No: 73 | Entry | Date: 2021-04-16 00:00:00 | Premium: 37.9 | Position: 1
# Trade No: 73 | Exit Type: Expiry or Signal Based | Date: 2021-04-19 00:00:00 | Premium: -25.4 | PnL: 12.5 | Cum PnL: 419.7
# ------------------------------
# Trade No: 74 | Entry | Date: 2021-04-30 00:00:00 | Premium: 0.8 | Position: 1
# Trade No: 74 | Exit Type: Expiry or Signal Based | Date: 2021-05-03 00:00:00 | Premium: -73.0 | PnL: -72.2 | Cum PnL: 347.5
# ------------------------------
# Trade No: 75 | Entry | Date: 2021-05-06 00:00:00 | Premium: 47.1 | Position: 1
# Trade No: 75 | Exit Type: SL | Date: 2021-05-07 00:00:00 | Premium: -71.2 | PnL: -24.1 | Cum PnL: 323.4
# ------------------------------
# Trade No: 76 | Entry | Date: 2021-05-10 00:00:00 | Premium: 60.6 | Position: 1
# Trade No: 76 | Exit Type: TP | Date: 2021-05-12 00:00:00 | Premium: -20.0 | PnL: 40.6 | Cum PnL: 364.0
# ------------------------------
# Trade No: 77 | Entry | Date: 2021-05-13 00:00:00 | Premium: 65.6 | Position: 1
# Trade No: 77 | Exit Type: Expiry or Signal Based | Date: 2021-05-14 00:00:00 | Premium: -90.4 | PnL: -24.9 | Cum PnL: 339.1
# ------------------------------
# Trade No: 78 | Entry | Date: 2021-05-19 00:00:00 | Premium: 40.2 | Position: 1
# Trade No: 78 | Exit Type: Expiry or Signal Based | Date: 2021-05-20 00:00:00 | Premium: -73.0 | PnL: -32.8 | Cum PnL: 306.3
# ------------------------------
# Trade No: 79 | Entry | Date: 2021-06-10 00:00:00 | Premium: 40.9 | Position: 1
# Trade No: 79 | Exit Type: Expiry or Signal Based | Date: 2021-06-11 00:00:00 | Premium: -38.5 | PnL: 2.4 | Cum PnL: 308.7
# ------------------------------
# Trade No: 80 | Entry | Date: 2021-06-22 00:00:00 | Premium: 24.7 | Position: 1
# Trade No: 80 | Exit Type: Expiry or Signal Based | Date: 2021-06-23 00:00:00 | Premium: -20.2 | PnL: 4.5 | Cum PnL: 313.2
# ------------------------------
# Trade No: 81 | Entry | Date: 2021-07-02 00:00:00 | Premium: 50.2 | Position: 1
# Trade No: 81 | Exit Type: days | Date: 2021-07-06 00:00:00 | Premium: -44.9 | PnL: 5.3 | Cum PnL: 318.5
# ------------------------------
# Trade No: 82 | Entry | Date: 2021-07-08 00:00:00 | Premium: 55.7 | Position: 1
# Trade No: 82 | Exit Type: SL | Date: 2021-07-12 00:00:00 | Premium: -88.9 | PnL: -33.2 | Cum PnL: 285.3
# ------------------------------
# Trade No: 83 | Entry | Date: 2021-07-14 00:00:00 | Premium: 41.2 | Position: 1
# Trade No: 83 | Exit Type: TP | Date: 2021-07-16 00:00:00 | Premium: -19.8 | PnL: 21.4 | Cum PnL: 306.7
# ------------------------------
# Trade No: 84 | Entry | Date: 2021-07-23 00:00:00 | Premium: 24.3 | Position: 1
# Trade No: 84 | Exit Type: Expiry or Signal Based | Date: 2021-07-26 00:00:00 | Premium: -27.3 | PnL: -3.0 | Cum PnL: 303.7
# ------------------------------
# Trade No: 85 | Entry | Date: 2021-07-29 00:00:00 | Premium: 9.5 | Position: 1
# Trade No: 85 | Exit Type: Expiry or Signal Based | Date: 2021-07-30 00:00:00 | Premium: -0.0 | PnL: 9.5 | Cum PnL: 313.2
# ------------------------------
# Trade No: 86 | Entry | Date: 2021-08-04 00:00:00 | Premium: 60.2 | Position: 1
# Trade No: 86 | Exit Type: days | Date: 2021-08-10 00:00:00 | Premium: -70.2 | PnL: -10.0 | Cum PnL: 303.2
# ------------------------------
# Trade No: 87 | Entry | Date: 2021-08-12 00:00:00 | Premium: 36.6 | Position: 1
# Trade No: 87 | Exit Type: Expiry or Signal Based | Date: 2021-08-16 00:00:00 | Premium: -40.5 | PnL: -3.9 | Cum PnL: 299.3
# ------------------------------
# Trade No: 88 | Entry | Date: 2021-08-20 00:00:00 | Premium: 32.0 | Position: 1
# Trade No: 88 | Exit Type: SL | Date: 2021-08-23 00:00:00 | Premium: -56.3 | PnL: -24.3 | Cum PnL: 275.0
# ------------------------------
# Trade No: 89 | Entry | Date: 2021-09-16 00:00:00 | Premium: 42.9 | Position: 1
# Trade No: 89 | Exit Type: TP | Date: 2021-09-20 00:00:00 | Premium: -9.0 | PnL: 33.9 | Cum PnL: 308.9
# ------------------------------
# Trade No: 90 | Entry | Date: 2021-09-21 00:00:00 | Premium: 59.0 | Position: 1
# Trade No: 90 | Exit Type: SL | Date: 2021-09-23 00:00:00 | Premium: -101.8 | PnL: -42.8 | Cum PnL: 266.1
# ------------------------------
# Trade No: 91 | Entry | Date: 2021-10-07 00:00:00 | Premium: 67.2 | Position: 1
# Trade No: 91 | Exit Type: days | Date: 2021-10-11 00:00:00 | Premium: -49.6 | PnL: 17.6 | Cum PnL: 283.7
# ------------------------------
# Trade No: 92 | Entry | Date: 2021-10-12 00:00:00 | Premium: 59.4 | Position: 1
# Trade No: 92 | Exit Type: Expiry or Signal Based | Date: 2021-10-13 00:00:00 | Premium: -63.7 | PnL: -4.3 | Cum PnL: 279.4
# ------------------------------
# Trade No: 93 | Entry | Date: 2021-10-20 00:00:00 | Premium: 29.0 | Position: 1
# Trade No: 93 | Exit Type: Expiry or Signal Based | Date: 2021-10-25 00:00:00 | Premium: -39.3 | PnL: -10.3 | Cum PnL: 269.1
# ------------------------------
# Trade No: 94 | Entry | Date: 2021-11-19 00:00:00 | Premium: 29.5 | Position: 1
# Trade No: 94 | Exit Type: Expiry or Signal Based | Date: 2021-11-22 00:00:00 | Premium: -24.1 | PnL: 5.4 | Cum PnL: 274.5
# ------------------------------
# Trade No: 95 | Entry | Date: 2021-12-02 00:00:00 | Premium: 116.4 | Position: 1
# Trade No: 95 | Exit Type: days | Date: 2021-12-06 00:00:00 | Premium: -117.6 | PnL: -1.2 | Cum PnL: 273.3
# ------------------------------
# Trade No: 96 | Entry | Date: 2021-12-07 00:00:00 | Premium: 73.1 | Position: 1
# Trade No: 96 | Exit Type: Expiry or Signal Based | Date: 2021-12-13 00:00:00 | Premium: -61.9 | PnL: 11.2 | Cum PnL: 284.5
# ------------------------------
# Trade No: 97 | Entry | Date: 2021-12-15 00:00:00 | Premium: 51.4 | Position: 1
# Trade No: 97 | Exit Type: TP | Date: 2021-12-17 00:00:00 | Premium: -25.1 | PnL: 26.3 | Cum PnL: 310.8
# ------------------------------
# Trade No: 98 | Entry | Date: 2021-12-20 00:00:00 | Premium: 57.6 | Position: 1
# Trade No: 98 | Exit Type: SL | Date: 2021-12-21 00:00:00 | Premium: -97.1 | PnL: -39.5 | Cum PnL: 271.3
# ------------------------------
# Trade No: 99 | Entry | Date: 2021-12-22 00:00:00 | Premium: 36.8 | Position: 1
# Trade No: 99 | Exit Type: SL | Date: 2021-12-23 00:00:00 | Premium: -56.6 | PnL: -19.8 | Cum PnL: 251.5
# ------------------------------
# Trade No: 100 | Entry | Date: 2022-01-24 00:00:00 | Premium: 73.2 | Position: 1
# Trade No: 100 | Exit Type: Expiry or Signal Based | Date: 2022-01-25 00:00:00 | Premium: -64.2 | PnL: 9.0 | Cum PnL: 260.5
# ------------------------------
# Trade No: 101 | Entry | Date: 2022-02-03 00:00:00 | Premium: 100.5 | Position: 1
# Trade No: 101 | Exit Type: Expiry or Signal Based | Date: 2022-02-07 00:00:00 | Premium: -80.0 | PnL: 20.5 | Cum PnL: 281.0
# ------------------------------
# Trade No: 102 | Entry | Date: 2022-02-23 00:00:00 | Premium: 53.4 | Position: 1
# Trade No: 102 | Exit Type: Expiry or Signal Based | Date: 2022-02-25 00:00:00 | Premium: -161.8 | PnL: -108.4 | Cum PnL: 172.6
# ------------------------------
# Trade No: 103 | Entry | Date: 2022-03-22 00:00:00 | Premium: 52.1 | Position: 1
# Trade No: 103 | Exit Type: TP | Date: 2022-03-23 00:00:00 | Premium: -27.5 | PnL: 24.6 | Cum PnL: 197.2
# ------------------------------
# Trade No: 104 | Entry | Date: 2022-03-24 00:00:00 | Premium: 42.0 | Position: 1
# Trade No: 104 | Exit Type: Expiry or Signal Based | Date: 2022-03-25 00:00:00 | Premium: -42.5 | PnL: -0.5 | Cum PnL: 196.7
# ------------------------------
# Trade No: 105 | Entry | Date: 2022-04-22 00:00:00 | Premium: 63.9 | Position: 1
# Trade No: 105 | Exit Type: Expiry or Signal Based | Date: 2022-04-25 00:00:00 | Premium: -68.1 | PnL: -4.2 | Cum PnL: 192.5
# ------------------------------
# Trade No: 106 | Entry | Date: 2022-05-03 00:00:00 | Premium: 121.1 | Position: 1
# Trade No: 106 | Exit Type: Expiry or Signal Based | Date: 2022-05-05 00:00:00 | Premium: -121.1 | PnL: 0.0 | Cum PnL: 192.5
# ------------------------------
# Trade No: 107 | Entry | Date: 2022-05-18 00:00:00 | Premium: 77.7 | Position: 1
# Trade No: 107 | Exit Type: Expiry or Signal Based | Date: 2022-05-19 00:00:00 | Premium: -74.8 | PnL: 2.9 | Cum PnL: 195.4
# ------------------------------
# Trade No: 108 | Entry | Date: 2022-05-20 00:00:00 | Premium: 69.0 | Position: 1
# Trade No: 108 | Exit Type: Expiry or Signal Based | Date: 2022-05-23 00:00:00 | Premium: -110.0 | PnL: -41.0 | Cum PnL: 154.4
# ------------------------------
# Trade No: 109 | Entry | Date: 2022-05-24 00:00:00 | Premium: 49.9 | Position: 1
# Trade No: 109 | Exit Type: SL | Date: 2022-05-25 00:00:00 | Premium: -78.5 | PnL: -28.6 | Cum PnL: 125.8
# ------------------------------
# Trade No: 110 | Entry | Date: 2022-05-26 00:00:00 | Premium: 41.2 | Position: 1
# Trade No: 110 | Exit Type: Expiry or Signal Based | Date: 2022-05-27 00:00:00 | Premium: -91.2 | PnL: -50.0 | Cum PnL: 75.8
# ------------------------------
# Trade No: 111 | Entry | Date: 2022-06-16 00:00:00 | Premium: 86.8 | Position: 1
# Trade No: 111 | Exit Type: SL | Date: 2022-06-21 00:00:00 | Premium: -130.3 | PnL: -43.5 | Cum PnL: 32.3
# ------------------------------
# Trade No: 112 | Entry | Date: 2022-06-22 00:00:00 | Premium: 74.6 | Position: 1
# Trade No: 112 | Exit Type: Expiry or Signal Based | Date: 2022-06-23 00:00:00 | Premium: -61.1 | PnL: 13.6 | Cum PnL: 45.9
# ------------------------------
# Trade No: 113 | Entry | Date: 2022-07-15 00:00:00 | Premium: 66.7 | Position: 1
# Trade No: 113 | Exit Type: Expiry or Signal Based | Date: 2022-07-19 00:00:00 | Premium: -108.4 | PnL: -41.7 | Cum PnL: 4.2
# ------------------------------
# Trade No: 114 | Entry | Date: 2022-07-20 00:00:00 | Premium: 59.8 | Position: 1
# Trade No: 114 | Exit Type: Expiry or Signal Based | Date: 2022-07-21 00:00:00 | Premium: -72.8 | PnL: -13.0 | Cum PnL: -8.8
# ------------------------------
# Trade No: 115 | Entry | Date: 2022-07-22 00:00:00 | Premium: 46.9 | Position: 1
# Trade No: 115 | Exit Type: Expiry or Signal Based | Date: 2022-07-26 00:00:00 | Premium: -25.0 | PnL: 21.9 | Cum PnL: 13.1
# ------------------------------
# Trade No: 116 | Entry | Date: 2022-07-29 00:00:00 | Premium: 1.5 | Position: 1
# Trade No: 116 | Exit Type: Expiry or Signal Based | Date: 2022-08-01 00:00:00 | Premium: -95.9 | PnL: -94.4 | Cum PnL: -81.3
# ------------------------------
# Trade No: 117 | Entry | Date: 2022-08-15 00:00:00 | Premium: 64.1 | Position: 1
# Trade No: 117 | Exit Type: Expiry or Signal Based | Date: 2022-08-16 00:00:00 | Premium: -61.4 | PnL: 2.7 | Cum PnL: -78.6
# ------------------------------
# Trade No: 118 | Entry | Date: 2022-08-19 00:00:00 | Premium: 51.4 | Position: 1
# Trade No: 118 | Exit Type: Expiry or Signal Based | Date: 2022-08-22 00:00:00 | Premium: -17.1 | PnL: 34.4 | Cum PnL: -44.2
# ------------------------------
# Trade No: 119 | Entry | Date: 2022-08-29 00:00:00 | Premium: 30.5 | Position: 1
# Trade No: 119 | Exit Type: TP | Date: 2022-08-30 00:00:00 | Premium: -5.4 | PnL: 25.1 | Cum PnL: -19.1
# ------------------------------
# Trade No: 120 | Entry | Date: 2022-08-31 00:00:00 | Premium: 4.8 | Position: 1
# Trade No: 120 | Exit Type: SL | Date: 2022-09-01 00:00:00 | Premium: -89.4 | PnL: -84.6 | Cum PnL: -103.7
# ------------------------------
# Trade No: 121 | Entry | Date: 2022-09-02 00:00:00 | Premium: 100.0 | Position: 1
# Trade No: 121 | Exit Type: Expiry or Signal Based | Date: 2022-09-06 00:00:00 | Premium: -93.7 | PnL: 6.3 | Cum PnL: -97.4
# ------------------------------
# Trade No: 122 | Entry | Date: 2022-09-08 00:00:00 | Premium: 70.1 | Position: 1
# Trade No: 122 | Exit Type: SL | Date: 2022-09-12 00:00:00 | Premium: -152.3 | PnL: -82.2 | Cum PnL: -179.6
# ------------------------------
# Trade No: 123 | Entry | Date: 2022-09-13 00:00:00 | Premium: 90.4 | Position: 1
# Trade No: 123 | Exit Type: TP | Date: 2022-09-16 00:00:00 | Premium: -48.7 | PnL: 41.7 | Cum PnL: -137.9
# ------------------------------
# Trade No: 124 | Entry | Date: 2022-09-19 00:00:00 | Premium: 72.1 | Position: 1
# Trade No: 124 | Exit Type: TP | Date: 2022-09-21 00:00:00 | Premium: -28.6 | PnL: 43.5 | Cum PnL: -94.4
# ------------------------------
# Trade No: 125 | Entry | Date: 2022-09-22 00:00:00 | Premium: 70.0 | Position: 1
# Trade No: 125 | Exit Type: Expiry or Signal Based | Date: 2022-09-23 00:00:00 | Premium: -30.6 | PnL: 39.4 | Cum PnL: -55.0
# ------------------------------
# Trade No: 126 | Entry | Date: 2022-09-26 00:00:00 | Premium: 64.9 | Position: 1
# ********* strategy_5
# ------------------------------
# Trade No: 127 | Entry | Date: 2020-10-13 00:00:00 | Premium: 60.3 | Position: 1
# Trade No: 127 | Exit Type: Expiry or Signal Based | Date: 2020-10-14 00:00:00 | Premium: -49.3 | PnL: 11.0 | Cum PnL: -44.0
# ------------------------------
# Trade No: 128 | Entry | Date: 2020-11-10 00:00:00 | Premium: 53.5 | Position: 1
# Trade No: 128 | Exit Type: Expiry or Signal Based | Date: 2020-11-11 00:00:00 | Premium: -53.5 | PnL: 0.0 | Cum PnL: -44.0
# ------------------------------
# Trade No: 129 | Entry | Date: 2020-11-12 00:00:00 | Premium: 56.2 | Position: 1
# Trade No: 129 | Exit Type: Expiry or Signal Based | Date: 2020-11-13 00:00:00 | Premium: -73.9 | PnL: -17.7 | Cum PnL: -61.7
# ------------------------------
# Trade No: 130 | Entry | Date: 2020-11-19 00:00:00 | Premium: 39.6 | Position: 1
# Trade No: 130 | Exit Type: days | Date: 2020-11-23 00:00:00 | Premium: -26.8 | PnL: 12.8 | Cum PnL: -48.9
# ------------------------------
# Trade No: 131 | Entry | Date: 2020-12-29 00:00:00 | Premium: 17.5 | Position: 1
# Trade No: 131 | Exit Type: Expiry or Signal Based | Date: 2020-12-30 00:00:00 | Premium: -17.4 | PnL: 0.1 | Cum PnL: -48.8
# ------------------------------
# Trade No: 132 | Entry | Date: 2021-01-27 00:00:00 | Premium: 42.2 | Position: 1
# Trade No: 132 | Exit Type: Expiry or Signal Based | Date: 2021-01-28 00:00:00 | Premium: -58.5 | PnL: -16.3 | Cum PnL: -65.1
# ------------------------------
# Trade No: 133 | Entry | Date: 2021-01-29 00:00:00 | Premium: 16.4 | Position: 1
# Trade No: 133 | Exit Type: Expiry or Signal Based | Date: 2021-02-01 00:00:00 | Premium: -114.3 | PnL: -97.9 | Cum PnL: -163.0
# ------------------------------
# Trade No: 134 | Entry | Date: 2021-11-10 00:00:00 | Premium: 71.2 | Position: 1
# Trade No: 134 | Exit Type: Expiry or Signal Based | Date: 2021-11-11 00:00:00 | Premium: -52.8 | PnL: 18.4 | Cum PnL: -144.6
# ------------------------------
# Trade No: 135 | Entry | Date: 2022-02-07 00:00:00 | Premium: 92.0 | Position: 1
# Trade No: 135 | Exit Type: Expiry or Signal Based | Date: 2022-02-08 00:00:00 | Premium: -90.2 | PnL: 1.8 | Cum PnL: -142.8
# ------------------------------
# Trade No: 136 | Entry | Date: 2022-03-07 00:00:00 | Premium: 206.7 | Position: 1
# Trade No: 136 | Exit Type: Expiry or Signal Based | Date: 2022-03-08 00:00:00 | Premium: -111.8 | PnL: 94.9 | Cum PnL: -47.9
# ------------------------------
# Trade No: 137 | Entry | Date: 2022-03-14 00:00:00 | Premium: 121.5 | Position: 1
# Trade No: 137 | Exit Type: Expiry or Signal Based | Date: 2022-03-15 00:00:00 | Premium: -121.5 | PnL: 0.0 | Cum PnL: -47.9
# ------------------------------
# Trade No: 138 | Entry | Date: 2022-05-05 00:00:00 | Premium: 116.2 | Position: 1
# Trade No: 138 | Exit Type: Expiry or Signal Based | Date: 2022-05-09 00:00:00 | Premium: -93.4 | PnL: 22.8 | Cum PnL: -25.1
# ------------------------------
# Trade No: 139 | Entry | Date: 2022-05-13 00:00:00 | Premium: 52.2 | Position: 1
# Trade No: 139 | Exit Type: SL | Date: 2022-05-16 00:00:00 | Premium: -78.8 | PnL: -26.6 | Cum PnL: -51.7
# ------------------------------
# Trade No: 140 | Entry | Date: 2022-07-07 00:00:00 | Premium: 95.4 | Position: 1
# Trade No: 140 | Exit Type: Expiry or Signal Based | Date: 2022-07-08 00:00:00 | Premium: -87.3 | PnL: 8.1 | Cum PnL: -43.6
# ------------------------------
# Trade No: 141 | Entry | Date: 2022-07-12 00:00:00 | Premium: 83.9 | Position: 1
# Trade No: 141 | Exit Type: Expiry or Signal Based | Date: 2022-07-13 00:00:00 | Premium: -83.7 | PnL: 0.2 | Cum PnL: -43.4
# ------------------------------
# Trade No: 142 | Entry | Date: 2022-08-09 00:00:00 | Premium: 78.4 | Position: 1
# Trade No: 142 | Exit Type: Expiry or Signal Based | Date: 2022-08-10 00:00:00 | Premium: -81.3 | PnL: -2.9 | Cum PnL: -46.3
# ------------------------------
# Trade No: 143 | Entry | Date: 2022-09-06 00:00:00 | Premium: 97.5 | Position: 1
# Trade No: 143 | Exit Type: Expiry or Signal Based | Date: 2022-09-08 00:00:00 | Premium: -139.0 | PnL: -41.5 | Cum PnL: -87.8
# ********* strategy_20
# ------------------------------
# Trade No: 144 | Entry | Date: 2020-10-14 00:00:00 | Premium: -5.4 | Position: 1
# Trade No: 144 | Exit Type: Expiry or Signal Based | Date: 2020-10-15 00:00:00 | Premium: -6.6 | PnL: -12.0 | Cum PnL: -99.8
# ------------------------------
# Trade No: 145 | Entry | Date: 2020-10-20 00:00:00 | Premium: -3.8 | Position: 1
# Trade No: 145 | Exit Type: Expiry or Signal Based | Date: 2020-10-21 00:00:00 | Premium: 0.6 | PnL: -3.2 | Cum PnL: -103.0
# ------------------------------
# Trade No: 146 | Entry | Date: 2020-11-03 00:00:00 | Premium: 27.6 | Position: 1
# Trade No: 146 | Exit Type: TP | Date: 2020-11-04 00:00:00 | Premium: 45.1 | PnL: 72.7 | Cum PnL: -30.3
# ------------------------------
# Trade No: 147 | Entry | Date: 2020-11-05 00:00:00 | Premium: 98.9 | Position: 1
# Trade No: 147 | Exit Type: TP | Date: 2020-11-06 00:00:00 | Premium: -4.3 | PnL: 94.6 | Cum PnL: 64.3
# ------------------------------
# Trade No: 148 | Entry | Date: 2020-11-11 00:00:00 | Premium: -0.7 | Position: 1
# Trade No: 148 | Exit Type: Expiry or Signal Based | Date: 2020-11-12 00:00:00 | Premium: -24.5 | PnL: -25.2 | Cum PnL: 39.1
# ------------------------------
# Trade No: 149 | Entry | Date: 2020-12-07 00:00:00 | Premium: 3.6 | Position: 1
# Trade No: 149 | Exit Type: TP | Date: 2020-12-08 00:00:00 | Premium: 12.8 | PnL: 16.4 | Cum PnL: 55.5
# ------------------------------
# Trade No: 150 | Entry | Date: 2020-12-09 00:00:00 | Premium: 1.7 | Position: 1
# Trade No: 150 | Exit Type: Expiry or Signal Based | Date: 2020-12-10 00:00:00 | Premium: 2.4 | PnL: 4.1 | Cum PnL: 59.6
# ------------------------------
# Trade No: 151 | Entry | Date: 2020-12-17 00:00:00 | Premium: 0.1 | Position: 1
# Trade No: 151 | Exit Type: Expiry or Signal Based | Date: 2020-12-18 00:00:00 | Premium: -22.2 | PnL: -22.0 | Cum PnL: 37.6
# ------------------------------
# Trade No: 152 | Entry | Date: 2021-01-06 00:00:00 | Premium: 1.3 | Position: 1
# Trade No: 152 | Exit Type: TP | Date: 2021-01-07 00:00:00 | Premium: 58.6 | PnL: 60.0 | Cum PnL: 97.6
# ------------------------------
# Trade No: 153 | Entry | Date: 2021-02-03 00:00:00 | Premium: -0.8 | Position: 1
# Trade No: 153 | Exit Type: TP | Date: 2021-02-04 00:00:00 | Premium: 29.2 | PnL: 28.4 | Cum PnL: 126.0
# ------------------------------
# Trade No: 154 | Entry | Date: 2021-02-05 00:00:00 | Premium: 4.8 | Position: 1
# Trade No: 154 | Exit Type: TP | Date: 2021-02-08 00:00:00 | Premium: 14.5 | PnL: 19.2 | Cum PnL: 145.2
# ------------------------------
# Trade No: 155 | Entry | Date: 2021-02-09 00:00:00 | Premium: 2.6 | Position: 1
# Trade No: 155 | Exit Type: Expiry or Signal Based | Date: 2021-02-10 00:00:00 | Premium: -8.4 | PnL: -5.8 | Cum PnL: 139.4
# ------------------------------
# Trade No: 156 | Entry | Date: 2021-02-11 00:00:00 | Premium: 6.9 | Position: 1
# Trade No: 156 | Exit Type: TP | Date: 2021-02-12 00:00:00 | Premium: 13.9 | PnL: 20.8 | Cum PnL: 160.2
# ------------------------------
# Trade No: 157 | Entry | Date: 2021-02-16 00:00:00 | Premium: -0.6 | Position: 1
# Trade No: 157 | Exit Type: TP | Date: 2021-02-17 00:00:00 | Premium: 1.2 | PnL: 0.6 | Cum PnL: 160.8
# ------------------------------
# Trade No: 158 | Entry | Date: 2021-02-24 00:00:00 | Premium: -1.7 | Position: 1
# Trade No: 158 | Exit Type: Expiry or Signal Based | Date: 2021-02-25 00:00:00 | Premium: -94.9 | PnL: -96.6 | Cum PnL: 64.2
# ------------------------------
# Trade No: 159 | Entry | Date: 2021-03-04 00:00:00 | Premium: -44.0 | Position: 1
# Trade No: 159 | Exit Type: SL | Date: 2021-03-05 00:00:00 | Premium: -1.6 | PnL: -45.6 | Cum PnL: 18.6
# ------------------------------
# Trade No: 160 | Entry | Date: 2021-03-08 00:00:00 | Premium: 5.8 | Position: 1
# Trade No: 160 | Exit Type: TP | Date: 2021-03-09 00:00:00 | Premium: 13.3 | PnL: 19.1 | Cum PnL: 37.7
# ------------------------------
# Trade No: 161 | Entry | Date: 2021-03-10 00:00:00 | Premium: 0.8 | Position: 1
# Trade No: 161 | Exit Type: Expiry or Signal Based | Date: 2021-03-11 00:00:00 | Premium: 42.6 | PnL: 43.4 | Cum PnL: 81.1
# ------------------------------
# Trade No: 162 | Entry | Date: 2021-03-24 00:00:00 | Premium: -1.9 | Position: 1
# Trade No: 162 | Exit Type: TP | Date: 2021-03-25 00:00:00 | Premium: 24.6 | PnL: 22.7 | Cum PnL: 103.8
# ------------------------------
# Trade No: 163 | Entry | Date: 2021-03-26 00:00:00 | Premium: 10.4 | Position: 1
# Trade No: 163 | Exit Type: SL | Date: 2021-03-30 00:00:00 | Premium: -21.0 | PnL: -10.6 | Cum PnL: 93.2
# ------------------------------
# Trade No: 164 | Entry | Date: 2021-03-31 00:00:00 | Premium: -2.4 | Position: 1
# Trade No: 164 | Exit Type: TP | Date: 2021-04-01 00:00:00 | Premium: 41.6 | PnL: 39.2 | Cum PnL: 132.4
# ------------------------------
# Trade No: 165 | Entry | Date: 2021-04-05 00:00:00 | Premium: -2.9 | Position: 1
# Trade No: 165 | Exit Type: SL | Date: 2021-04-06 00:00:00 | Premium: -1.6 | PnL: -4.5 | Cum PnL: 127.9
# ------------------------------
# Trade No: 166 | Entry | Date: 2021-04-14 00:00:00 | Premium: 1.5 | Position: 1
# Trade No: 166 | Exit Type: TP | Date: 2021-04-15 00:00:00 | Premium: 39.0 | PnL: 40.5 | Cum PnL: 168.4
# ------------------------------
# Trade No: 167 | Entry | Date: 2021-04-26 00:00:00 | Premium: 4.1 | Position: 1
# Trade No: 167 | Exit Type: TP | Date: 2021-04-27 00:00:00 | Premium: -2.0 | PnL: 2.1 | Cum PnL: 170.5
# ------------------------------
# Trade No: 168 | Entry | Date: 2021-04-28 00:00:00 | Premium: 2.0 | Position: 1
# Trade No: 168 | Exit Type: TP | Date: 2021-04-29 00:00:00 | Premium: 25.0 | PnL: 27.0 | Cum PnL: 197.5
# ------------------------------
# Trade No: 169 | Entry | Date: 2021-05-03 00:00:00 | Premium: -0.9 | Position: 1
# Trade No: 169 | Exit Type: SL | Date: 2021-05-04 00:00:00 | Premium: -39.4 | PnL: -40.3 | Cum PnL: 157.2
# ------------------------------
# Trade No: 170 | Entry | Date: 2021-05-05 00:00:00 | Premium: 4.8 | Position: 1
# Trade No: 170 | Exit Type: Expiry or Signal Based | Date: 2021-05-06 00:00:00 | Premium: 5.2 | PnL: 10.0 | Cum PnL: 167.2
# ------------------------------
# Trade No: 171 | Entry | Date: 2021-05-25 00:00:00 | Premium: 3.0 | Position: 1
# Trade No: 171 | Exit Type: Expiry or Signal Based | Date: 2021-05-26 00:00:00 | Premium: 4.9 | PnL: 7.9 | Cum PnL: 175.1
# ------------------------------
# Trade No: 172 | Entry | Date: 2021-05-27 00:00:00 | Premium: -6.2 | Position: 1
# Trade No: 172 | Exit Type: SL | Date: 2021-06-01 00:00:00 | Premium: -0.6 | PnL: -6.8 | Cum PnL: 168.3
# ------------------------------
# Trade No: 173 | Entry | Date: 2021-06-02 00:00:00 | Premium: 8.7 | Position: 1
# Trade No: 173 | Exit Type: SL | Date: 2021-06-03 00:00:00 | Premium: -12.3 | PnL: -3.6 | Cum PnL: 164.7
# ------------------------------
# Trade No: 174 | Entry | Date: 2021-06-04 00:00:00 | Premium: 2.6 | Position: 1
# Trade No: 174 | Exit Type: SL | Date: 2021-06-07 00:00:00 | Premium: -10.4 | PnL: -7.8 | Cum PnL: 156.9
# ------------------------------
# Trade No: 175 | Entry | Date: 2021-06-08 00:00:00 | Premium: -3.2 | Position: 1
# Trade No: 175 | Exit Type: SL | Date: 2021-06-09 00:00:00 | Premium: -5.0 | PnL: -8.2 | Cum PnL: 148.7
# ------------------------------
# Trade No: 176 | Entry | Date: 2021-06-17 00:00:00 | Premium: -5.4 | Position: 1
# Trade No: 176 | Exit Type: Expiry or Signal Based | Date: 2021-06-18 00:00:00 | Premium: -40.1 | PnL: -45.5 | Cum PnL: 103.2
# ------------------------------
# Trade No: 177 | Entry | Date: 2021-06-23 00:00:00 | Premium: -1.0 | Position: 1
# Trade No: 177 | Exit Type: TP | Date: 2021-06-24 00:00:00 | Premium: 25.7 | PnL: 24.7 | Cum PnL: 127.9
# ------------------------------
# Trade No: 178 | Entry | Date: 2021-06-25 00:00:00 | Premium: -2.0 | Position: 1
# Trade No: 178 | Exit Type: TP | Date: 2021-06-28 00:00:00 | Premium: 10.1 | PnL: 8.1 | Cum PnL: 136.0
# ------------------------------
# Trade No: 179 | Entry | Date: 2021-06-29 00:00:00 | Premium: -1.3 | Position: 1
# Trade No: 179 | Exit Type: TP | Date: 2021-06-30 00:00:00 | Premium: 7.6 | PnL: 6.3 | Cum PnL: 142.3
# ------------------------------
# Trade No: 180 | Entry | Date: 2021-07-01 00:00:00 | Premium: 5.3 | Position: 1
# Trade No: 180 | Exit Type: Expiry or Signal Based | Date: 2021-07-02 00:00:00 | Premium: 29.7 | PnL: 35.0 | Cum PnL: 177.3
# ------------------------------
# Trade No: 181 | Entry | Date: 2021-07-26 00:00:00 | Premium: -1.4 | Position: 1
# Trade No: 181 | Exit Type: SL | Date: 2021-07-27 00:00:00 | Premium: -24.4 | PnL: -25.8 | Cum PnL: 151.5
# ------------------------------
# Trade No: 182 | Entry | Date: 2021-07-28 00:00:00 | Premium: -1.7 | Position: 1
# Trade No: 182 | Exit Type: Expiry or Signal Based | Date: 2021-07-29 00:00:00 | Premium: 19.4 | PnL: 17.7 | Cum PnL: 169.2
# ------------------------------
# Trade No: 183 | Entry | Date: 2021-07-30 00:00:00 | Premium: -0.6 | Position: 1
# Trade No: 183 | Exit Type: TP | Date: 2021-08-03 00:00:00 | Premium: 71.0 | PnL: 70.4 | Cum PnL: 239.6
# ------------------------------
# Trade No: 184 | Entry | Date: 2021-08-18 00:00:00 | Premium: -2.4 | Position: 1
# Trade No: 184 | Exit Type: TP | Date: 2021-08-19 00:00:00 | Premium: 13.4 | PnL: 11.0 | Cum PnL: 250.6
# ------------------------------
# Trade No: 185 | Entry | Date: 2021-08-26 00:00:00 | Premium: -0.0 | Position: 1
# Trade No: 185 | Exit Type: TP | Date: 2021-08-27 00:00:00 | Premium: 41.4 | PnL: 41.4 | Cum PnL: 292.0
# ------------------------------
# Trade No: 186 | Entry | Date: 2021-08-30 00:00:00 | Premium: 1.1 | Position: 1
# Trade No: 186 | Exit Type: SL | Date: 2021-09-01 00:00:00 | Premium: -8.1 | PnL: -7.0 | Cum PnL: 285.0
# ------------------------------
# Trade No: 187 | Entry | Date: 2021-09-02 00:00:00 | Premium: 2.4 | Position: 1
# Trade No: 187 | Exit Type: TP | Date: 2021-09-03 00:00:00 | Premium: 0.8 | PnL: 3.2 | Cum PnL: 288.2
# ------------------------------
# Trade No: 188 | Entry | Date: 2021-09-10 00:00:00 | Premium: 0.4 | Position: 1
# Trade No: 188 | Exit Type: Expiry or Signal Based | Date: 2021-09-13 00:00:00 | Premium: 2.8 | PnL: 3.2 | Cum PnL: 291.4
# ------------------------------
# Trade No: 189 | Entry | Date: 2021-09-14 00:00:00 | Premium: -4.7 | Position: 1
# Trade No: 189 | Exit Type: Expiry or Signal Based | Date: 2021-09-16 00:00:00 | Premium: 22.0 | PnL: 17.3 | Cum PnL: 308.7
# ------------------------------
# Trade No: 190 | Entry | Date: 2021-09-24 00:00:00 | Premium: 3.7 | Position: 1
# Trade No: 190 | Exit Type: Expiry or Signal Based | Date: 2021-09-27 00:00:00 | Premium: -12.4 | PnL: -8.7 | Cum PnL: 300.0
# ------------------------------
# Trade No: 191 | Entry | Date: 2021-09-30 00:00:00 | Premium: -9.0 | Position: 1
# Trade No: 191 | Exit Type: TP | Date: 2021-10-01 00:00:00 | Premium: 50.3 | PnL: 41.3 | Cum PnL: 341.3
# ------------------------------
# Trade No: 192 | Entry | Date: 2021-10-04 00:00:00 | Premium: 7.4 | Position: 1
# Trade No: 192 | Exit Type: TP | Date: 2021-10-05 00:00:00 | Premium: 56.8 | PnL: 64.2 | Cum PnL: 405.5
# ------------------------------
# Trade No: 193 | Entry | Date: 2021-10-06 00:00:00 | Premium: 33.6 | Position: 1
# Trade No: 193 | Exit Type: Expiry or Signal Based | Date: 2021-10-07 00:00:00 | Premium: 39.2 | PnL: 72.8 | Cum PnL: 478.3
# ------------------------------
# Trade No: 194 | Entry | Date: 2021-10-18 00:00:00 | Premium: 1.0 | Position: 1
# Trade No: 194 | Exit Type: TP | Date: 2021-10-19 00:00:00 | Premium: 27.9 | PnL: 28.9 | Cum PnL: 507.2
# ------------------------------
# Trade No: 195 | Entry | Date: 2021-10-25 00:00:00 | Premium: 0.3 | Position: 1
# Trade No: 195 | Exit Type: TP | Date: 2021-10-26 00:00:00 | Premium: 10.4 | PnL: 10.7 | Cum PnL: 517.9
# ------------------------------
# Trade No: 196 | Entry | Date: 2021-10-27 00:00:00 | Premium: -3.9 | Position: 1
# Trade No: 196 | Exit Type: TP | Date: 2021-10-28 00:00:00 | Premium: 44.9 | PnL: 41.0 | Cum PnL: 558.9
# ------------------------------
# Trade No: 197 | Entry | Date: 2021-10-29 00:00:00 | Premium: -1.6 | Position: 1
# Trade No: 197 | Exit Type: SL | Date: 2021-11-01 00:00:00 | Premium: -3.1 | PnL: -4.7 | Cum PnL: 554.2
# ------------------------------
# Trade No: 198 | Entry | Date: 2021-11-15 00:00:00 | Premium: 6.5 | Position: 1
# Trade No: 198 | Exit Type: TP | Date: 2021-11-16 00:00:00 | Premium: 22.2 | PnL: 28.7 | Cum PnL: 582.9
# ------------------------------
# Trade No: 199 | Entry | Date: 2021-11-17 00:00:00 | Premium: -1.5 | Position: 1
# Trade No: 199 | Exit Type: TP | Date: 2021-11-18 00:00:00 | Premium: 15.0 | PnL: 13.5 | Cum PnL: 596.4
# ------------------------------
# Trade No: 200 | Entry | Date: 2021-11-24 00:00:00 | Premium: -1.5 | Position: 1
# Trade No: 200 | Exit Type: SL | Date: 2021-11-26 00:00:00 | Premium: -92.2 | PnL: -93.7 | Cum PnL: 502.7
# ------------------------------
# Trade No: 201 | Entry | Date: 2021-11-29 00:00:00 | Premium: -1.2 | Position: 1
# Trade No: 201 | Exit Type: SL | Date: 2021-11-30 00:00:00 | Premium: -80.6 | PnL: -81.8 | Cum PnL: 420.9
# ------------------------------
# Trade No: 202 | Entry | Date: 2021-12-01 00:00:00 | Premium: -69.9 | Position: 1
# Trade No: 202 | Exit Type: Expiry or Signal Based | Date: 2021-12-02 00:00:00 | Premium: 65.1 | PnL: -4.8 | Cum PnL: 416.1
# ------------------------------
# Trade No: 203 | Entry | Date: 2021-12-27 00:00:00 | Premium: -2.0 | Position: 1
# Trade No: 203 | Exit Type: Expiry or Signal Based | Date: 2021-12-28 00:00:00 | Premium: -5.3 | PnL: -7.3 | Cum PnL: 408.8
# ------------------------------
# Trade No: 204 | Entry | Date: 2021-12-29 00:00:00 | Premium: 0.6 | Position: 1
# Trade No: 204 | Exit Type: SL | Date: 2021-12-30 00:00:00 | Premium: -16.4 | PnL: -15.8 | Cum PnL: 393.0
# ------------------------------
# Trade No: 205 | Entry | Date: 2021-12-31 00:00:00 | Premium: -1.9 | Position: 1
# Trade No: 205 | Exit Type: Expiry or Signal Based | Date: 2022-01-03 00:00:00 | Premium: 17.6 | PnL: 15.7 | Cum PnL: 408.7
# ------------------------------
# Trade No: 206 | Entry | Date: 2022-01-07 00:00:00 | Premium: -2.0 | Position: 1
# Trade No: 206 | Exit Type: SL | Date: 2022-01-10 00:00:00 | Premium: -67.6 | PnL: -69.6 | Cum PnL: 339.1
# ------------------------------
# Trade No: 207 | Entry | Date: 2022-01-12 00:00:00 | Premium: 5.3 | Position: 1
# Trade No: 207 | Exit Type: Expiry or Signal Based | Date: 2022-01-13 00:00:00 | Premium: -44.5 | PnL: -39.2 | Cum PnL: 299.9
# ------------------------------
# Trade No: 208 | Entry | Date: 2022-01-18 00:00:00 | Premium: 0.6 | Position: 1
# Trade No: 208 | Exit Type: Expiry or Signal Based | Date: 2022-01-19 00:00:00 | Premium: 21.8 | PnL: 22.4 | Cum PnL: 322.3
# ------------------------------
# Trade No: 209 | Entry | Date: 2022-01-25 00:00:00 | Premium: 0.1 | Position: 1
# Trade No: 209 | Exit Type: SL | Date: 2022-01-26 00:00:00 | Premium: -10.6 | PnL: -10.5 | Cum PnL: 311.8
# ------------------------------
# Trade No: 210 | Entry | Date: 2022-01-27 00:00:00 | Premium: -7.5 | Position: 1
# Trade No: 210 | Exit Type: TP | Date: 2022-01-28 00:00:00 | Premium: 101.5 | PnL: 94.0 | Cum PnL: 405.8
# ------------------------------
# Trade No: 211 | Entry | Date: 2022-01-31 00:00:00 | Premium: -0.4 | Position: 1
# Trade No: 211 | Exit Type: SL | Date: 2022-02-01 00:00:00 | Premium: -1.3 | PnL: -1.7 | Cum PnL: 404.1
# ------------------------------
# Trade No: 212 | Entry | Date: 2022-02-02 00:00:00 | Premium: 7.6 | Position: 1
# Trade No: 212 | Exit Type: Expiry or Signal Based | Date: 2022-02-03 00:00:00 | Premium: -45.8 | PnL: -38.2 | Cum PnL: 365.9
# ------------------------------
# Trade No: 213 | Entry | Date: 2022-02-25 00:00:00 | Premium: 0.9 | Position: 1
# Trade No: 213 | Exit Type: SL | Date: 2022-02-28 00:00:00 | Premium: -17.3 | PnL: -16.4 | Cum PnL: 349.5
# ------------------------------
# Trade No: 214 | Entry | Date: 2022-03-01 00:00:00 | Premium: 1.8 | Position: 1
# Trade No: 214 | Exit Type: Expiry or Signal Based | Date: 2022-03-03 00:00:00 | Premium: 14.0 | PnL: 15.8 | Cum PnL: 365.3
# ------------------------------
# Trade No: 215 | Entry | Date: 2022-03-04 00:00:00 | Premium: 17.4 | Position: 1
# ...
# ------------------------------
# Trade No: 225 | Entry | Date: 2022-05-19 00:00:00 | Premium: -6.6 | Position: 1
# Trade No: 225 | Exit Type: Expiry or Signal Based | Date: 2022-05-20 00:00:00 | Premium: -36.5 | PnL: -43.1 | Cum PnL: 420.2
# ------------------------------
# Trade No: 226 | Entry | Date: 2022-05-27 00:00:00 | Premium: 7.0 | Position: 1
# Trade No: 226 | Exit Type: SL | Date: 2022-05-31 00:00:00 | Premium: -27.8 | PnL: -20.8 | Cum PnL: 399.4
# ------------------------------
# Trade No: 227 | Entry | Date: 2022-06-15 00:00:00 | Premium: 24.9 | Position: 1
# Trade No: 227 | Exit Type: Expiry or Signal Based | Date: 2022-06-16 00:00:00 | Premium: -89.5 | PnL: -64.6 | Cum PnL: 334.8
# ------------------------------
# Trade No: 228 | Entry | Date: 2022-06-28 00:00:00 | Premium: -3.4 | Position: 1
# Trade No: 228 | Exit Type: SL | Date: 2022-06-29 00:00:00 | Premium: 1.8 | PnL: -1.6 | Cum PnL: 333.2
# ------------------------------
# Trade No: 229 | Entry | Date: 2022-06-30 00:00:00 | Premium: 11.3 | Position: 1
# Trade No: 229 | Exit Type: Expiry or Signal Based | Date: 2022-07-01 00:00:00 | Premium: 12.8 | PnL: 24.1 | Cum PnL: 357.3
# ------------------------------
# Trade No: 230 | Entry | Date: 2022-07-26 00:00:00 | Premium: 0.7 | Position: 1
# Trade No: 230 | Exit Type: TP | Date: 2022-07-27 00:00:00 | Premium: 101.0 | PnL: 101.7 | Cum PnL: 459.0
# ------------------------------
# Trade No: 231 | Entry | Date: 2022-07-28 00:00:00 | Premium: -1.3 | Position: 1
# Trade No: 231 | Exit Type: Expiry or Signal Based | Date: 2022-07-29 00:00:00 | Premium: 63.2 | PnL: 61.9 | Cum PnL: 520.9
# ------------------------------
# Trade No: 232 | Entry | Date: 2022-08-16 00:00:00 | Premium: 2.7 | Position: 1
# Trade No: 232 | Exit Type: SL | Date: 2022-08-17 00:00:00 | Premium: -12.3 | PnL: -9.6 | Cum PnL: 511.3
# ------------------------------
# Trade No: 233 | Entry | Date: 2022-08-18 00:00:00 | Premium: 5.9 | Position: 1
# Trade No: 233 | Exit Type: Expiry or Signal Based | Date: 2022-08-19 00:00:00 | Premium: -54.4 | PnL: -48.5 | Cum PnL: 462.8
# ------------------------------
# Trade No: 234 | Entry | Date: 2022-08-22 00:00:00 | Premium: 3.1 | Position: 1
# Trade No: 234 | Exit Type: SL | Date: 2022-08-23 00:00:00 | Premium: -5.0 | PnL: -1.9 | Cum PnL: 460.9
# ------------------------------
# Trade No: 235 | Entry | Date: 2022-08-24 00:00:00 | Premium: -5.3 | Position: 1
# Trade No: 235 | Exit Type: TP | Date: 2022-08-25 00:00:00 | Premium: 28.6 | PnL: 23.3 | Cum PnL: 484.2
# ------------------------------
# Trade No: 236 | Entry | Date: 2022-08-26 00:00:00 | Premium: -15.9 | Position: 1
# Trade No: 236 | Exit Type: Expiry or Signal Based | Date: 2022-08-29 00:00:00 | Premium: -25.5 | PnL: -41.4 | Cum PnL: 442.8
# ------------------------------
# Trade No: 237 | Entry | Date: 2022-09-23 00:00:00 | Premium: 8.9 | Position: 1
# Trade No: 237 | Exit Type: Expiry or Signal Based | Date: 2022-09-26 00:00:00 | Premium: -36.4 | PnL: -27.5 | Cum PnL: 415.3
# ********* strategy_11
# ------------------------------
# Trade No: 238 | Entry | Date: 2020-10-15 00:00:00 | Premium: 58.7 | Position: 1
# Trade No: 238 | Exit Type: Expiry or Signal Based | Date: 2020-10-16 00:00:00 | Premium: -53.2 | PnL: 5.5 | Cum PnL: 420.8
# ------------------------------
# Trade No: 239 | Entry | Date: 2020-11-09 00:00:00 | Premium: 60.1 | Position: 1
# Trade No: 239 | Exit Type: Expiry or Signal Based | Date: 2020-11-10 00:00:00 | Premium: -71.6 | PnL: -11.5 | Cum PnL: 409.3
# ------------------------------
# Trade No: 240 | Entry | Date: 2020-12-10 00:00:00 | Premium: 54.8 | Position: 1
# Trade No: 240 | Exit Type: days | Date: 2020-12-14 00:00:00 | Premium: -62.6 | PnL: -7.9 | Cum PnL: 401.4
# ------------------------------
# Trade No: 241 | Entry | Date: 2020-12-16 00:00:00 | Premium: 43.8 | Position: 1
# Trade No: 241 | Exit Type: Expiry or Signal Based | Date: 2020-12-17 00:00:00 | Premium: -35.1 | PnL: 8.7 | Cum PnL: 410.1
# ------------------------------
# Trade No: 242 | Entry | Date: 2020-12-18 00:00:00 | Premium: 38.0 | Position: 1
# Trade No: 242 | Exit Type: Expiry or Signal Based | Date: 2020-12-21 00:00:00 | Premium: -54.8 | PnL: -16.8 | Cum PnL: 393.3
# ------------------------------
# Trade No: 243 | Entry | Date: 2020-12-22 00:00:00 | Premium: 37.0 | Position: 1
# Trade No: 243 | Exit Type: Expiry or Signal Based | Date: 2020-12-23 00:00:00 | Premium: -26.7 | PnL: 10.3 | Cum PnL: 403.6
# ------------------------------
# Trade No: 244 | Entry | Date: 2020-12-30 00:00:00 | Premium: 8.5 | Position: 1
# Trade No: 244 | Exit Type: Expiry or Signal Based | Date: 2020-12-31 00:00:00 | Premium: -0.0 | PnL: 8.5 | Cum PnL: 412.1
# ------------------------------
# Trade No: 245 | Entry | Date: 2021-01-20 00:00:00 | Premium: 34.6 | Position: 1
# Trade No: 245 | Exit Type: days | Date: 2021-01-25 00:00:00 | Premium: -24.5 | PnL: 10.1 | Cum PnL: 422.2
# ------------------------------
# Trade No: 246 | Entry | Date: 2021-02-10 00:00:00 | Premium: 57.1 | Position: 1
# Trade No: 246 | Exit Type: Expiry or Signal Based | Date: 2021-02-11 00:00:00 | Premium: -48.1 | PnL: 9.0 | Cum PnL: 431.2
# ------------------------------
# Trade No: 247 | Entry | Date: 2021-02-23 00:00:00 | Premium: 25.4 | Position: 1
# Trade No: 247 | Exit Type: Expiry or Signal Based | Date: 2021-02-24 00:00:00 | Premium: -6.5 | PnL: 18.9 | Cum PnL: 450.1
# ------------------------------
# Trade No: 248 | Entry | Date: 2021-03-02 00:00:00 | Premium: 75.1 | Position: 1
# Trade No: 248 | Exit Type: Expiry or Signal Based | Date: 2021-03-04 00:00:00 | Premium: -113.5 | PnL: -38.4 | Cum PnL: 411.7
# ------------------------------
# Trade No: 249 | Entry | Date: 2021-03-12 00:00:00 | Premium: 61.5 | Position: 1
# Trade No: 249 | Exit Type: Expiry or Signal Based | Date: 2021-03-15 00:00:00 | Premium: -45.3 | PnL: 16.2 | Cum PnL: 427.9
# ------------------------------
# Trade No: 250 | Entry | Date: 2021-03-18 00:00:00 | Premium: 47.9 | Position: 1
# Trade No: 250 | Exit Type: TP | Date: 2021-03-22 00:00:00 | Premium: -23.9 | PnL: 24.0 | Cum PnL: 451.9
# ------------------------------
# Trade No: 251 | Entry | Date: 2021-03-23 00:00:00 | Premium: 40.7 | Position: 1
# Trade No: 251 | Exit Type: Expiry or Signal Based | Date: 2021-03-24 00:00:00 | Premium: -41.5 | PnL: -0.8 | Cum PnL: 451.1
# ------------------------------
# Trade No: 252 | Entry | Date: 2021-04-07 00:00:00 | Premium: 55.9 | Position: 1
# Trade No: 252 | Exit Type: TP | Date: 2021-04-12 00:00:00 | Premium: -32.3 | PnL: 23.6 | Cum PnL: 474.7
# ------------------------------
# Trade No: 253 | Entry | Date: 2021-04-19 00:00:00 | Premium: 42.4 | Position: 1
# Trade No: 253 | Exit Type: SL | Date: 2021-04-20 00:00:00 | Premium: -65.9 | PnL: -23.5 | Cum PnL: 451.2
# ------------------------------
# Trade No: 254 | Entry | Date: 2021-04-21 00:00:00 | Premium: 34.8 | Position: 1
# Trade No: 254 | Exit Type: SL | Date: 2021-04-22 00:00:00 | Premium: -56.8 | PnL: -22.0 | Cum PnL: 429.2
# ------------------------------
# Trade No: 255 | Entry | Date: 2021-04-23 00:00:00 | Premium: 26.2 | Position: 1
# Trade No: 255 | Exit Type: Expiry or Signal Based | Date: 2021-04-26 00:00:00 | Premium: -20.1 | PnL: 6.1 | Cum PnL: 435.3
# ------------------------------
# Trade No: 256 | Entry | Date: 2021-05-14 00:00:00 | Premium: 45.0 | Position: 1
# Trade No: 256 | Exit Type: days | Date: 2021-05-18 00:00:00 | Premium: -55.9 | PnL: -10.9 | Cum PnL: 424.4
# ------------------------------
# Trade No: 257 | Entry | Date: 2021-05-21 00:00:00 | Premium: 33.8 | Position: 1
# Trade No: 257 | Exit Type: TP | Date: 2021-05-24 00:00:00 | Premium: -10.0 | PnL: 23.8 | Cum PnL: 448.2
# ------------------------------
# Trade No: 258 | Entry | Date: 2021-05-26 00:00:00 | Premium: 14.9 | Position: 1
# Trade No: 258 | Exit Type: Expiry or Signal Based | Date: 2021-05-27 00:00:00 | Premium: -5.6 | PnL: 9.3 | Cum PnL: 457.5
# ------------------------------
# Trade No: 259 | Entry | Date: 2021-06-11 00:00:00 | Premium: 42.6 | Position: 1
# Trade No: 259 | Exit Type: days | Date: 2021-06-15 00:00:00 | Premium: -37.5 | PnL: 5.1 | Cum PnL: 462.6
# ------------------------------
# Trade No: 260 | Entry | Date: 2021-06-18 00:00:00 | Premium: 43.0 | Position: 1
# Trade No: 260 | Exit Type: TP | Date: 2021-06-21 00:00:00 | Premium: -18.2 | PnL: 24.8 | Cum PnL: 487.4
# ------------------------------
# Trade No: 261 | Entry | Date: 2021-07-07 00:00:00 | Premium: 51.9 | Position: 1
# Trade No: 261 | Exit Type: Expiry or Signal Based | Date: 2021-07-08 00:00:00 | Premium: -77.8 | PnL: -25.9 | Cum PnL: 461.5
# ------------------------------
# Trade No: 262 | Entry | Date: 2021-07-13 00:00:00 | Premium: 47.1 | Position: 1
# Trade No: 262 | Exit Type: Expiry or Signal Based | Date: 2021-07-14 00:00:00 | Premium: -41.0 | PnL: 6.1 | Cum PnL: 467.6
# ------------------------------
# Trade No: 263 | Entry | Date: 2021-07-19 00:00:00 | Premium: 64.9 | Position: 1
# Trade No: 263 | Exit Type: TP | Date: 2021-07-20 00:00:00 | Premium: -23.6 | PnL: 41.3 | Cum PnL: 508.9
# ------------------------------
# Trade No: 264 | Entry | Date: 2021-07-21 00:00:00 | Premium: 33.6 | Position: 1
# Trade No: 264 | Exit Type: Expiry or Signal Based | Date: 2021-07-23 00:00:00 | Premium: -10.4 | PnL: 23.2 | Cum PnL: 532.1
# ------------------------------
# Trade No: 265 | Entry | Date: 2021-08-11 00:00:00 | Premium: 45.4 | Position: 1
# Trade No: 265 | Exit Type: Expiry or Signal Based | Date: 2021-08-12 00:00:00 | Premium: -35.8 | PnL: 9.6 | Cum PnL: 541.7
# ------------------------------
# Trade No: 266 | Entry | Date: 2021-08-16 00:00:00 | Premium: 36.6 | Position: 1
# Trade No: 266 | Exit Type: Expiry or Signal Based | Date: 2021-08-18 00:00:00 | Premium: -49.0 | PnL: -12.4 | Cum PnL: 529.3
# ------------------------------
# Trade No: 267 | Entry | Date: 2021-08-25 00:00:00 | Premium: 14.8 | Position: 1
# Trade No: 267 | Exit Type: Expiry or Signal Based | Date: 2021-08-26 00:00:00 | Premium: -30.4 | PnL: -15.6 | Cum PnL: 513.7
# ------------------------------
# Trade No: 268 | Entry | Date: 2021-09-08 00:00:00 | Premium: 55.3 | Position: 1
# Trade No: 268 | Exit Type: Expiry or Signal Based | Date: 2021-09-10 00:00:00 | Premium: -86.5 | PnL: -31.2 | Cum PnL: 482.5
# ------------------------------
# Trade No: 269 | Entry | Date: 2021-09-13 00:00:00 | Premium: 56.0 | Position: 1
# Trade No: 269 | Exit Type: Expiry or Signal Based | Date: 2021-09-14 00:00:00 | Premium: -63.8 | PnL: -7.8 | Cum PnL: 474.7
# ------------------------------
# Trade No: 270 | Entry | Date: 2021-09-27 00:00:00 | Premium: 19.4 | Position: 1
# Trade No: 270 | Exit Type: Expiry or Signal Based | Date: 2021-09-28 00:00:00 | Premium: -90.0 | PnL: -70.6 | Cum PnL: 404.1
# ------------------------------
# Trade No: 271 | Entry | Date: 2021-09-29 00:00:00 | Premium: 20.0 | Position: 1
# Trade No: 271 | Exit Type: Expiry or Signal Based | Date: 2021-09-30 00:00:00 | Premium: -44.4 | PnL: -24.4 | Cum PnL: 379.7
# ------------------------------
# Trade No: 272 | Entry | Date: 2021-10-13 00:00:00 | Premium: 55.6 | Position: 1
# Trade No: 272 | Exit Type: TP | Date: 2021-10-14 00:00:00 | Premium: -26.9 | PnL: 28.6 | Cum PnL: 408.3
# ------------------------------
# Trade No: 273 | Entry | Date: 2021-10-15 00:00:00 | Premium: 38.3 | Position: 1
# Trade No: 273 | Exit Type: Expiry or Signal Based | Date: 2021-10-18 00:00:00 | Premium: -29.4 | PnL: 8.9 | Cum PnL: 417.2
# ------------------------------
# Trade No: 274 | Entry | Date: 2021-11-05 00:00:00 | Premium: 55.6 | Position: 1
# Trade No: 274 | Exit Type: Expiry or Signal Based | Date: 2021-11-08 00:00:00 | Premium: -53.2 | PnL: 2.3 | Cum PnL: 419.5
# ------------------------------
# Trade No: 275 | Entry | Date: 2021-11-11 00:00:00 | Premium: 52.2 | Position: 1
# Trade No: 275 | Exit Type: Expiry or Signal Based | Date: 2021-11-15 00:00:00 | Premium: -33.0 | PnL: 19.2 | Cum PnL: 438.7
# ------------------------------
# Trade No: 276 | Entry | Date: 2021-11-22 00:00:00 | Premium: 21.1 | Position: 1
# Trade No: 276 | Exit Type: Expiry or Signal Based | Date: 2021-11-24 00:00:00 | Premium: -17.4 | PnL: 3.7 | Cum PnL: 442.4
# ------------------------------
# Trade No: 277 | Entry | Date: 2021-12-14 00:00:00 | Premium: 65.8 | Position: 1
# Trade No: 277 | Exit Type: Expiry or Signal Based | Date: 2021-12-15 00:00:00 | Premium: -34.8 | PnL: 31.0 | Cum PnL: 473.4
# ------------------------------
# Trade No: 278 | Entry | Date: 2021-12-28 00:00:00 | Premium: 19.9 | Position: 1
# Trade No: 278 | Exit Type: Expiry or Signal Based | Date: 2021-12-29 00:00:00 | Premium: -10.8 | PnL: 9.1 | Cum PnL: 482.5
# ------------------------------
# Trade No: 279 | Entry | Date: 2022-01-04 00:00:00 | Premium: 62.7 | Position: 1
# Trade No: 279 | Exit Type: Expiry or Signal Based | Date: 2022-01-05 00:00:00 | Premium: -77.1 | PnL: -14.4 | Cum PnL: 468.1
# ------------------------------
# Trade No: 280 | Entry | Date: 2022-01-11 00:00:00 | Premium: 70.4 | Position: 1
# Trade No: 280 | Exit Type: Expiry or Signal Based | Date: 2022-01-12 00:00:00 | Premium: -60.8 | PnL: 9.6 | Cum PnL: 477.7
# ------------------------------
# Trade No: 281 | Entry | Date: 2022-01-14 00:00:00 | Premium: 62.0 | Position: 1
# Trade No: 281 | Exit Type: Expiry or Signal Based | Date: 2022-01-18 00:00:00 | Premium: -115.6 | PnL: -53.6 | Cum PnL: 424.1
# ------------------------------
# Trade No: 282 | Entry | Date: 2022-01-19 00:00:00 | Premium: 67.8 | Position: 1
# Trade No: 282 | Exit Type: Expiry or Signal Based | Date: 2022-01-21 00:00:00 | Premium: -134.8 | PnL: -67.0 | Cum PnL: 357.1
# ------------------------------
# Trade No: 283 | Entry | Date: 2022-02-09 00:00:00 | Premium: 68.1 | Position: 1
# Trade No: 283 | Exit Type: SL | Date: 2022-02-10 00:00:00 | Premium: -125.9 | PnL: -57.8 | Cum PnL: 299.3
# ------------------------------
# Trade No: 284 | Entry | Date: 2022-02-11 00:00:00 | Premium: 84.9 | Position: 1
# Trade No: 284 | Exit Type: Expiry or Signal Based | Date: 2022-02-14 00:00:00 | Premium: -88.6 | PnL: -3.7 | Cum PnL: 295.6
# ------------------------------
# Trade No: 285 | Entry | Date: 2022-02-16 00:00:00 | Premium: 63.9 | Position: 1
# Trade No: 285 | Exit Type: Expiry or Signal Based | Date: 2022-02-17 00:00:00 | Premium: -96.8 | PnL: -32.9 | Cum PnL: 262.7
# ------------------------------
# Trade No: 286 | Entry | Date: 2022-03-10 00:00:00 | Premium: 109.4 | Position: 1
# Trade No: 286 | Exit Type: Expiry or Signal Based | Date: 2022-03-11 00:00:00 | Premium: -112.9 | PnL: -3.5 | Cum PnL: 259.2
# ------------------------------
# Trade No: 287 | Entry | Date: 2022-03-17 00:00:00 | Premium: 75.4 | Position: 1
# Trade No: 287 | Exit Type: Expiry or Signal Based | Date: 2022-03-21 00:00:00 | Premium: -55.3 | PnL: 20.1 | Cum PnL: 279.3
# ------------------------------
# Trade No: 288 | Entry | Date: 2022-05-23 00:00:00 | Premium: 60.7 | Position: 1
# Trade No: 288 | Exit Type: Expiry or Signal Based | Date: 2022-05-24 00:00:00 | Premium: -111.9 | PnL: -51.2 | Cum PnL: 228.1
# ------------------------------
# Trade No: 289 | Entry | Date: 2022-06-03 00:00:00 | Premium: 106.0 | Position: 1
# Trade No: 289 | Exit Type: Expiry or Signal Based | Date: 2022-06-06 00:00:00 | Premium: -106.0 | PnL: 0.0 | Cum PnL: 228.1
# ------------------------------
# Trade No: 290 | Entry | Date: 2022-06-23 00:00:00 | Premium: 66.9 | Position: 1
# Trade No: 290 | Exit Type: Expiry or Signal Based | Date: 2022-06-27 00:00:00 | Premium: -8.9 | PnL: 58.0 | Cum PnL: 286.1
# ********* strategy_18
# ------------------------------
# Trade No: 291 | Entry | Date: 2020-10-16 00:00:00 | Premium: -10.5 | Position: 1
# Trade No: 291 | Exit Type: Expiry or Signal Based | Date: 2020-10-19 00:00:00 | Premium: -54.5 | PnL: -65.0 | Cum PnL: 221.1
# ------------------------------
# Trade No: 292 | Entry | Date: 2020-12-15 00:00:00 | Premium: 11.6 | Position: 1
# Trade No: 292 | Exit Type: Expiry or Signal Based | Date: 2020-12-16 00:00:00 | Premium: 13.8 | PnL: 25.4 | Cum PnL: 246.5
# ********* strategy_25
# ------------------------------
# Trade No: 293 | Entry | Date: 2022-07-21 00:00:00 | Premium: -110.3 | Position: 1
# Trade No: 293 | Exit Type: Expiry or Signal Based | Date: 2022-07-22 00:00:00 | Premium: 99.2 | PnL: -11.1 | Cum PnL: 235.4

# %%
# Round trip details
round_trips_details.head()
# Out:
#   Option Type  Strike Price  position  entry_price entry_date  exit_date  \
# 0        call        3445.0        -1        66.45 2020-10-08 2020-10-09
# 1         put        3445.0         1        70.09 2020-10-08 2020-10-09
# 2  underlying        3445.0        -1         0.00 2020-10-08 2020-10-09
# 0        call        3425.0        -1        52.50 2020-10-19 2020-10-20
# 1         put        3425.0         1        53.45 2020-10-19 2020-10-20
#
#                 exit_type  exit_price
# 0  Expiry or Signal Based       77.44
# 1  Expiry or Signal Based       49.90
# 2  Expiry or Signal Based        0.00
# 0  Expiry or Signal Based       60.60
# 1  Expiry or Signal Based       41.80

# %%
# MTM details
mark_to_market.head()
# Out:
#   Option Type  Strike Price  position  premium       Date
# 0        call        3445.0        -1    66.45 2020-10-08
# 1         put        3445.0         1    70.09 2020-10-08
# 2  underlying        3445.0        -1     0.00 2020-10-08
# 0        call        3445.0        -1    77.44 2020-10-09
# 1         put        3445.0         1    49.90 2020-10-09

# %% [raw]
# ## Save the dataframes 'round_trips_details' and 'mark_to_market' as CSV files to use in next notebooks
# round_trips_details.to_csv('../data_modules/round_trips_LSTM_mlo.csv')
# mark_to_market.to_csv('../data_modules/mark_to_market_LSTM_mlo.csv')

# %% [markdown]
# ## Conclusion
# In this notebook, we have backtested the strategies predicted by the LSTM model. Using the dataframes `round_trips_details` and `mark_to_market` we will analyse the trades in the next notebook.
